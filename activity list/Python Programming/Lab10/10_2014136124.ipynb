# %% [markdown]
# # 문제 1번.
#
# (숫자 빈도수 세기) 사용자가 입력하는 정수를 읽고 이 중에 가장 많이 나온 숫자를 찾아 출력하는 프로그램을 작성하시오. 예를 들어, 2 3 40 5 4 -3 3 3 2 0을 입력하면, 숫자 3이 가장 많이 나온 숫자이다. 사용자는 한 행에 모든 숫자들을 입력하며 입력하는 정수의 개수에 제한은 없다. 가장 많이 나온 숫자의 개수가 여러 개일 경우, 이들 숫자 모두를 찾아야 한다. 예를 들어, 9 30 3 9 3 2 4를 입력했을 경우 9와 3이 두 번씩 가장 많이 나온다. 이 경우, 9와 3을 모두 찾아 결과로 출력해야만 한다.

# %%
user_lst = list(map(int, input("숫자 입력:").split())) # 입력받은 문자열을 split() 메소드와 map 메소드를 이용하여 정수형 리스트 형태로 바꿔줌
user_dic = {} # 빈 딕셔너리 생성

for digit in user_lst: 
    # 만약 단어를 저장하는 딕셔너리에 단어가 포함되어 있다면(중복되면)
    if digit in user_dic:
        # 개수를 하나 더 추가
        user_dic[digit] += 1
    # 만약 단어가 포함되어 있지 않다면(처음이라면)
    else:
        # 개수를 1로 만든다
        user_dic[digit] = 1
        
maxNum = [] # 최대 빈도수를 가진 key값을 넣어줄 리스트

maxCnt = max(user_dic.values()) # 가장 큰 빈도수는 딕셔너리의 값 중 가장 큰 수

for key in user_dic: # 딕셔너리 원소 중 key값에서 
    if maxCnt == user_dic[key]: # maxCnt와 같은 값이면
        maxNum.append(key) # 최대 빈도수 리스트에 추가
        
print("가장 많은 빈도수를 가진 숫자:", end = ' ')
for x in maxNum:
    print(x, end = ' ')
# Out:
# 숫자 입력:9 30 3 9 3 2 4
# 가장 많은 빈도수를 가진 숫자: 9 3

# %% [markdown]
# ## 코드에 대한 설명
#
# 문제 1번은 딕셔너리와 리스트를 함께 활용해서 풀어보았다. 우선, 사용자로부터 숫자를 입력받은 것을 정수형 리스트로 변환해주었다. 그 다음 빈 딕셔너리를 생성하고 정수형 리스트의 원소 중에서 만약 딕셔너리의 key값에 없다면 딕셔너리의 그 해당하는 key 값의 value의 값을 1만큼씩 늘린다. 그 다음은 이 문제에서 구하고자 하는 내용은 value의 값이 큰 key값들을 출력해주는 것이다. 그러므로 우선, value의 값이 제일 큰 것을 찾아야 한다. 여기에서 생성해준 딕셔너리의 value의 값은 입력받은 정수형 리스트의 원소의 빈도수와 같다. 그러므로 최대 빈도수를 가지는(value의 값을 가지는) key값을 따로 저장해줄 리스트를 하나 생성한다. 또한, 가장 큰 빈도수를 할당해줄 maxCnt라는 변수에 max() 메소드를 이용하여 value의 값을 할당해준다.
#
# for loop 구문을 이용하여 딕셔너리 원소 중 key값 중에서 만약 maxCnt와 같은 값이 나오면 최대 빈도수를 가지는 리스트 maxNum에 추가를 해준다. 이렇게 추가된 값은 바로 최대 빈도수를 가지는 key값이다. 이를 출력하면 된다.

# %% [markdown]
# # 문제 2번.
#
# (자음과 모음 수 세기) 사용자로부터 텍스트 파일명을 입력받고 이 파일 내에 있는 영문자 자음과 모음의 수를 각각 출력하는 프로그램을 작성하시오. 모음 A, E, I, O, U를 저장하기 위해 세트를 사용하라.

# %%
# 예외처리를 이용하여 파일 입출력 확인
try:
    fileName = input("파일 이름 입력:").strip()
    openFile = open(fileName, "r")
except IOError:
    print("File open fail")
else:
    print("File open success")
finally:
    print("finally절이 실행되었습니다")
    
copyString = openFile.read().upper() # 모든 문자열 대문자로 변환

StringList = list(copyString.split()) # 문자열 리스트 생성

StringSet = set() # 문자열 리스트를 세트로 변환해주기 위한 빈 세트 생성

collection = set(['A', 'E', 'I', 'O', 'U']) # 모음 집합

StringCollectionCnt = 0  # 모음의 개수를 세주는 변수

for word in StringList: # 문자열 리스트의 원소 중에서
    for char in word: # 그 원소의 문자 중에서
        StringSet.add(char) # 세트의 원소에 문자를 추가
        if char == 'A' or char == 'E' or char == 'I' or char == 'O' or char == 'U': # 만약 문자가 모음이면
            collectionCnt += 1 # 모음의 개수 1씩 증가
            
print("모음의 수:", collectionCnt)
print("모음 집합:", StringSet.intersection(collection)) # 파일 내에 있는 모음의 집합
# Out:
# 파일 이름 입력:test.txt
# File open success
# finally절이 실행되었습니다
# 모음의 수: 378294
# 모음 집합: {'I', 'O', 'E', 'U', 'A'}

# %% [markdown]
# ## 코드에 대한 설명
#
# 문제 2번은 사실 아직까지도 제대로 푼 것인지 문제를 이해를 확실하게 못해서 확신하질 못하겠다. 먼저, 파일의 있는 텍스트 내용을 읽어와야 하므로 예외 처리를 이용하여 파일 입출력에 대한 예외 처리를 해주었다. 만약, 파일 열기가 성공하면 파일의 내용을 하나의 문자열에 대문자로 변환하여서 저장한다. 대문자나 소문자로 변환해야지 문제에서 주어진 모음의 개수나 혹은 자음의 개수를 세기가 훨씬 용이하다. 그 다음은 문자열 리스트를 아까 입력받은 문자열로 만들어 준다. 문자열 리스트를 만든 이유는 문자열 리스트의 원소 중에서 하나 하나 문자에 접근하여 모음과 자음의 개수를 세 주기 위해서이다. 제시된 조건 중 set를 이용하라에서 만약 set로 만들어 버리면(리스트를 세트로 변환하면) 중복이 사라져서 정확한 모음과 자음의 개수를 세기가 어렵다.
#
# 그 다음은 모음만 가지고 있는 집합을 생성해준다. 나중에 이 집합과 비교를 할 것이다. 마지막으로 for loop를 이용하여 문자열 리스트의 원소 중에서 그 원소의 각각의 문자에 접근하여 그 문자를 새로운 set에 추가해준다. 이 set는 StringSet로 전체 문자열의 set형태라고 보면 된다. 만약 문자가 모음이라면 모음의 개수를 1씩 증가시켜준다. 만약 아니라면을 가정하고 자음의 개수를 1씩 증가시켜준다고 생각하면 큰 오산이다. 문자열 리스트에는 특수문자나 공백문자가 포함되어 있기 때문에 나머지라고 하면 이들과 자음이 모두 포함되기 때문에 정확한 값이 나오지 않는다. 만약 자음의 개수를 따로 세주고 싶다면
# ```
# consonant = [consonant for char in StringSet if (char.isalpha() == True) and (char != 'A' or char != 'E' or char != 'I' or char != 'O' or char != 'U')]
# ```
# 의 리스트를 이용하여 개수를 구해주면 된다.

# %% [markdown]
# # 문제 3번.
#
# (0 옮기기) 배열 num을 감안할 때 0이 아닌 요소의 상대적인 순서를 유지하면서 0을 모두 끝으로 이동시키는 함수를 작성하시오.

# %% [markdown]
# ![Q3.JPG](attachment:Q3.JPG)

# %% [markdown]
# ## 코드에 대한 설명
#
# 문제 3번이 제일 간단한 문제라고 생각된다. 일단 문제에 대해 보충 설명하자면, nums = [0, 1, 0, 3, 12]라는 정해진 리스트가 있는데 이 리스트의 원소 중 0의 값이 있다면 이 0의 값을 모두 리스트의 마지막으로 옮기는 문제이다. 따라서 코드를 짠다면 먼저 이 리스트의 각 원소에 접근하여서 그 원소가 만약 0의 값이면 insert() 메소드를 이용하여 리스트의 가장 마지막 위치에 0에 해당하는 값을 옮겨준다. 그리고나서 그 위치의 원소를 remove() 메소드를 이용하여 제거해준다. 제거를 하지 않으면 원소가 두 번 중복되기 때문이다.

# %% [markdown]
# # 문제 4번.
#
# (인접 문자 출력) 문자열을 지정하면 한 문자 또는 두 개의 인접 문자 다음에 문자열을 분할하고 한 문자 또는 두 문자로만 구성된 문자열을 만들 수 있습니다. 가능한 모든 결과를 출력하시오.

# %%
stringList = list(input(""))

def func1(stringLst):
    lst1 = []
    lst2 = []
    
    for i in range(len(stringList)):
        for j in range(len(stringList)):
            lst2 = []
            if i == j:
                continue
            else:
                if j == i + 1 and j <= len(stringList):
                    lst2.append(stringList[i] + stringList[j])
                    for i in range(len(stringList)):
                        lst2.append(stringList[i])
                else:
                    continue
            lst1.append(lst2)    
    return lst1

func1(stringList)
# Out:
# abcd
# [['ab', 'a', 'b', 'c', 'd'],
#  ['bc', 'a', 'b', 'c', 'd'],
#  ['cd', 'a', 'b', 'c', 'd']]

# %% [markdown]
# # 코드에 대한 설명
#
# 문제 4번은 너무 너무 어렵다. 그래서 조교님께서 힌트로 깊이 우선 탐색과 재귀 스킬이 필요하다고 알려주셨고 어떤 블로그에서 그래프 깊이 우선 탐색을 설명해주었다. 사실 글을 읽으면서 완전히 이해하지 못했다. 자료구조를 이번에 안들어서 이진 트리라던지 뭔가 새로운 용어들이 와닿지를 않았다. 하지만 대충 어떤 느낌인지 감은 잡혔다. 그래서 코드를 직접 쓰진 못했지만 생각은 구현이 된거 같다. 일단 생각한 내용이 깊이 우선 탐색이라는 것이 위에서부터 아래로 쭉 내려가는 것이다. 즉, 하나 하나 다 탐색을 하면서 마지막까지 가는 것이다. 그래서 이번 문제를 적용해보자면 만약 abcd라는 문자열을 받게 된다면, a부터 d까지 모든 원소에 하나하나 탐색을 한다. 처음 재귀는 아마도 원소 하나씩 탐색이므로 a, b, c, d로 갈 것이다. 여기서 블로그에서는 white, black이라는 색상으로 표시해주었지만 나는 이 원소들을 하나씩 만나면 1을, 만나지 않으면 0을 주겠다. a부터 d 원소까지 모두 만났으므로 모든 원소는 1로 저장되고, 재귀가 끝나는 순간 모두 0으로 바꾸어 준다.
#
# 두 번째 재귀는 원소를 두 개씩 묶는 것이다. 아마도 이 함수가 시작되면 ab, ac, ad, ba, bc, bd와 같은 순서로 d까지 갈 것이다. 그리고 이때 마지막에 위에 첫 번째 재귀함수에서 나온 a, b, c, d 원소를 넣어준 리스트에 두 번째 재귀 함수에서 결과 값에서 서로 인접한 것끼리만 추출하여 리스트에 추가해준다. 그리고 다시 이 두 번째 재귀함수가 끝나면 첫 번째 재귀함수를 호출하여 ab가 있는 리스트라면, c와 d 원소가 없으므로 이 원소들을 넣어준다. 이런 식을 반복하면 뭔가 깊이 우선 탐색을 사용하는 것 같다.
#
# 결론적으로 실력이 부족하여 코드를 짜지 못했지만 이번 방학을 통해 파이썬에 대해 좀 더 공부도 하고 자료구조도 다음 학기를 위해서 미리 공부하여 이 문제에 대해 고찰해볼 것이다.
