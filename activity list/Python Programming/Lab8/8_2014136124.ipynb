# %% [markdown]
# # 문제 1번.
#
# (중복값 제거하기) 주어진 리스트에 대해서 중복값이 제거된 새로운 리스트를 반환하는 함수를 작성하시오. 다음의 함수 헤더를 사용하라.
#
# *
# def eliminateDuplicates(lst):
# *
#
# 사용자로부터 정수 리스트를 입력받고, 위 함수를 호출하여 얻은 결과를 출력하는 테스트 프로그램을 작성하시오.

# %%
def eliminateDuplicates(lst):
    eliminatelst = [] # 중복을 제거한 리스트를 담기 위한 리스트
    for i in lst: # i의 값은 매개변수로 받은 리스트의 원소 
        if i not in eliminatelst: # 만약 eliminatelst에 i의 값이 없다면
            eliminatelst.append(i) #  eliminatelst에 i의 값을 추가
    for i in range(len(eliminatelst)): # eliminatelst를 출력
        print(eliminatelst[i], end = " ")

user_lst = input("10개의 숫자를 입력하세요:");
change_user_string_lst = user_lst.split() # 입력된 문자열을 split으로 문자열 리스트로 변환
change_user_digit_lst = list(map(int, change_user_string_lst)) # 문자열 리스트를 정수형 리스트로 변환

print("중복을 제거한 고유한 숫자:", end = "")
eliminateDuplicates(change_user_digit_lst)
# Out:
# 10개의 숫자를 입력하세요:1 2 3 2 1 6 3 4 5 2
# 중복을 제거한 고유한 숫자:1 2 3 6 4 5

# %% [markdown]
# ## 코드에 대한 설명
#
# 문제 1번은 리스트에서 하나 이상의 중복된 값을 제거해주는 함수를 만드는 문제이다. 기본 알고리즘은 사용자로부터 입력받은 리스트를 정수형 리스트로 바꾸어주고 그 리스트의 원소를 첫 번째 원소부터 시작해서 마지막 원소까지 접근하여 빈 리스트에 하나씩 담아준다. 이 빈 리스트는 중복을 제거한 리스트이다. 매개변수의 리스트의 원소를 for문을 이용하여 반복문을 돌린다. 이렇게 하면 원소의 값 하나씩 접근이 가능해진다. range를 쓰는 경우는 리스트의 인덱스 값을 받아서 리스트의 원소에 접근하는 것이다. 만약 빈 리스트에 매개변수 리스트의 원소가 없다면 append 메소드를 이용하여 추가해준다. 만약 원소가 있다면 반복을 해준다. 마지막에 중복이 제거된 리스트를 출력해준다.

# %% [markdown]
# # 문제 2번.
#
# (시뮬레이션: 쿠폰 수집가 문제) 쿠폰 수집가 문제는 다양한 실전 응용을 가진 고전적인 통계 문제이다. 이 문제는 객체 집합에서 반복적으로 객체를 뽑고, 모든 객체가 적어도 한 번씩 선택되기 위해 얼마나 많은 시도가 필요한지를 알아내는 것이다. 이 문제를 52장의 뒤섞여진 카드로 구성된 카드팩에서 반복해서 카드를 뽑고 모든 종류의 카드가 선택되기까지 얼마나 많은 시도가 필요한지를 알아내는 문제로 변형해 보자. 뽑은 카드는 카드팩에 다시 넣는다고 가정한다. 4장의 카드를 얻기 위해 시도한 횟수를 시뮬레이션하며 뽑은 4장의 카드를 출력하는 프로그램을 작성하시오(1장의 카드가 두 번 뽑힐 수도 있다).

# %%
import random

NUM = 10 # 1 ~ 10
TYPE = ["Spade", "Clover", "Heart", "Diamond"] 
PICTURE = ["King", "Queen", "Jack"] 

# 트럼프 카드 만들기
# 트럼프의 개수는 총 52장
Trump = []

# NUM * TYPE의 형태로 40장, TYPE * PICTURE의 형태로 12장
NUM_TYPE = []
TYPE_PICTURE = []

for type_item in TYPE: # Spade(0), Clover(1), Heart(2), Diamond(3)
    for j in range(NUM): # 1 ~ 10(0 ~ 9)
        NUM_TYPE.append([type_item, j + 1]) # 리스트에 리스트를 추가하여 2차원 배열 생성, NUM_TYPE 형태의 카드 40장 생성
    for pic_item in PICTURE: # King(1), Queen(2), Jack(3) 
        TYPE_PICTURE.append([type_item, pic_item]) # TYPE_PICTURE 형태의 카드 12장 생성

Trump = NUM_TYPE + TYPE_PICTURE # 트럼프 카드는 NUM_TYPE 카드와 TYPE_PICTURE 카드를 합친 것

# 카드 셔플하기
random.shuffle(Trump) 


# ------------------------------------------------------------------------------------------------------------------------------------------
# 제가 이해한 카드 뽑기는 우선 네 종류(스페이드, 클로버, 하트, 다이아몬드) 중에서 하나를 선택합니다
# 그리고 뽑은 하나를 제외한 나머지 세 종류가 나올 때까지 계속해서 선택합니다
# 그 다음 역시나 마찬가지로 앞의 두 종류의 카드를 제외한 나머지 종류의 카드를 하나 뽑습니다
# 마지막에 뽑은 카드까지 해서 모두 서로 다른 종류의 카드가 된다면 시행횟수를 종료합니다
# 여기서 질문드리고 싶은 것이 처음 58번째 줄에서 만약 두 번째 카드와 세 번째 카드가 중복이 된다면
# 세 번째 카드를 버리고 다시 뽑아야 하는데 if~else문을 사용하면 두 번째 카드까지 다시 초기화가 됩니다
# 마찬가지로 네 번째 카드와 세 번째 카드도 중복이 된다면 다시 처음부터 두 번째 카드부터 다시 뽑아야 됩니다
# 이거를 if~else문으로 어떻게 구현해야 될지 잘 모르겠습니다
# 코드를 작성하다보니 하드코딩이 되는 것 같아서 코드를 수정해야 될 것 같습니다.


# selectCard = [] # 선택된 카드가 담기는 리스트
# selectCard_count = 0 # 선택된 카드가 담기는 리스트를 세주는 변수
# total_count = 0 # 전체 시행 횟수

# randomSelect1 = random.randrange(len(Trump)) # 첫 번째 랜덤 카드
# selectCard.append(Trump[randomSelect1]) # 선택된 카드 리스트에 추가
# print("randomSelect1:", Trump[randomSelect1][0])
# selectCard_count += 1
# total_count += 1

# for card in Trump:
#     randomSelect2 = random.randrange(len(Trump))  # 두 번째 랜덤 카드
    
#     if Trump[randomSelect1][0] == Trump[randomSelect2][0]: # 만약 두 번째 카드가 첫 번째 카드와 중복되면 반복문 다시 실행
#         total_count += 1                                   # 두 번째 카드까지는 사실 다시 반복해도 상관이 없다
#     elif Trump[randomSelect1][0] != Trump[randomSelect2][0] and selectCard_count == 1: 
#         selectCard.append(Trump[randomSelect2]) # 선택된 카드 리스트에 추가
#         print("randomSelect2:", Trump[randomSelect2][0])
#         selectCard_count += 1
#         total_count += 1
        
#         randomSelect3 = random.randrange(len(Trump)) # 세 번째 랜덤 카드
        
#         if Trump[randomSelect3][0] == Trump[randomSelect2][0] or Trump[randomSelect3][0] == Trump[randomSelect1][0]: # 여기서부터 문제
#             total_count += 1
#         elif Trump[randomSelect3][0] != Trump[randomSelect2][0] and Trump[randomSelect3][0] != Trump[randomSelect1][0] and selectCard_count == 2:
#             selectCard.append(Trump[randomSelect3])
#             print("randomSelect3:", Trump[randomSelect3][0])
#             selectCard_count += 1
#             total_count += 1
            
#             randomSelect4 = random.randrange(len(Trump)) # 네 번째 랜덤 카드
            
#             if Trump[randomSelect4][0] == Trump[randomSelect3][0] or Trump[randomSelect4][0] == Trump[randomSelect2][0] or Trump[randomSelect4][0] == Trump[randomSelect1][0]:
#                 total_count += 1
#             elif Trump[randomSelect4][0] != Trump[randomSelect3][0] and Trump[randomSelect4][0] != Trump[randomSelect2][0] and Trump[randomSelect4][0] != Trump[randomSelect1][0] and selectCard_count == 3:
#                 selectCard.append(Trump[randomSelect4])
#                 print("randomSelect4:", Trump[randomSelect4][0])
#                 selectCard_count += 1
#                 total_count += 1
#                 print(total_count)
# ------------------------------------------------------------------------------------------------------------------------------------------


# 다시 생각해본 코드
# 각각의 모양에 대해 True와 False의 값이 담긴 리스트를 생성
# 카드를 뽑을 때 선택된 모양이 나올 경우 True
# 선택된 모양이 나오지 않을 경우 다시 뽑기
selectCard = [] # 선택된 카드가 담기는 리스트
boolSelect = [False, False, False, False] # 각각 Spade, Clover, Heart, Diamond
bool_count =  4 * [0] # boolSelect의 변환 횟수
total_count = 0 # 전체 시행 횟수

while True: # 무한 루프를 돌린다(조건은 boolSelect의 원소들이 모두 True일때 탈출한다)
    randomSelect = random.randrange(len(Trump)) # 랜덤으로 카드를 하나 뽑는다
    total_count += 1 # 전체 시행 횟수를 한 번 증가한다(이 위치에 있으면 카드를 뽑을 때마다 한 번씩 카운트 된다)
    
    # while문 탈출 조건
    if boolSelect[0] == True and boolSelect[1] == True and boolSelect[2] == True and boolSelect[3] == True:
        for i in range(len(selectCard)):
            print(selectCard[i][0], end = " ") 
            print(selectCard[i][1]) # 뽑힌 카드를 출력
        print("뽑은 횟수:", total_count) # 전체 시행 횟수를 출력
        break # 반복문 탈출
        
    if Trump[randomSelect][0] == "Spade": # 만약 모양이 Spade가 나온다면
        if boolSelect[0] == True: # boolSelect의 첫 번째 값(Spade일 때만)이 이미 True이면
            continue # 카드를 다시 뽑는다
        else: # 첫 번째 값이 False이면
            boolSelect[0] = True # boolSelect의 첫 번째 값을 True로 변환
            if bool_count[0] == 0: # 만약 bool_count의 첫 번째 값(Spade일 때만)이 0이라면
                selectCard.append(Trump[randomSelect]) # 선택된 카드를 준비된 리스트에 추가해준다
                bool_count[0] += 1 # bool_count의 첫 번째 값이 1로 증가한다
            else: # bool_count의 첫 번째 값이 0이 아니라면
                continue # 카드를 다시 뽑는다
    # 마찬가지로 Clover부터해서 Diamond까지 같은 방법을 이용해준다
    elif Trump[randomSelect][0] == "Clover":
        if boolSelect[1] == True:
            continue
        else:
            boolSelect[1] = True
            if bool_count[1] == 0:
                selectCard.append(Trump[randomSelect])
                bool_count[1] += 1
            else:
                continue
    elif Trump[randomSelect][0] == "Heart":
        if boolSelect[2] == True:
            continue
        else:
            boolSelect[2] = True
            if bool_count[2] == 0:
                selectCard.append(Trump[randomSelect])
                bool_count[2] += 1
            else:
                continue
    elif Trump[randomSelect][0] == "Diamond":
        if boolSelect[3] == True:
            continue    
        else:
            boolSelect[3] = True
            if bool_count[3] == 0:
                selectCard.append(Trump[randomSelect])
                bool_count[3] += 1
            else:
                continue
# Out:
# Clover 9
# Diamond 7
# Heart Jack
# Spade 7
# 뽑은 횟수: 9

# %% [markdown]
# ## 코드에 대한 설명
#
# 문제 2번은 정말 지금까지 했던 코딩 중에 가장 어려웠던 문제이다. 제시된 문제를 간단하게 요약하자면 트럼프 카드 52장 중에서 사용자가 4장을 연속으로 뽑을 건데 이 4장의 카드의 모양이 서로 다를 때까지 카드를 뽑아야 한다. 예를 들어, 만약 처음 뽑은 카드가 스페이드이면 나머지 3장의 카드는 스페이드 이외의 모양이 나와야 한다. 이런 방식을 가지고 프로그램이 동작해야 한다.
#
# 우선, 트럼프 카드의 52장을 만들어 주어야 한다. 트럼프 카드는 숫자는 Ace부터 10까지이고, 모양은 Spade, Clover, Heart, Diamond가 있고, 그림은 King, Queen, Jack이 있다. 모양은 각 숫자와 그림에 붙어 있다. 따라서 경우의 수는 10 * 4 = 40과 4 * 3 = 12로 총 52장의 카드가 구성된다. 따라서 숫자와 모양이 있는 카드를 구성하는 리스트, 모양과 그림이 있는 카드를 구성하는 리스트를 만들어 준다. 각각 NUM_TYPE과 TYPE_PICTURE의 리스트로 조교님이 알려주신 방법으로 각각의 원소를 초기화 하였다. TYPE 리스트가 중복이 되기 때문에 이 리스트의 원소를 for문의 가장 밖에서 반복을 해준다. 그리고 숫자와 그림 각각의 길이에 따라서 append 메소드를 이용하여 원소를 추가해준다. 이렇게 구성된 두 리스트를 합쳐서 Trump라는 52장의 카드로 구성된 리스트를 만든다. NUM_TYPE 리스트와 TYPE_PICTURE의 리스트는 모두 2차원 배열이므로 Trump 리스트 역시나 2차원 배열이다.
#
# 그다음은 문제에서 제시된 카드를 랜덤으로 섞어서 카드를 뽑는 과정이다. 그렇기에 random 모듈을 import하여서 shuffle 메소드를 이용하여 리스트의 원소를 섞어 준다.
#
# 여기서부터 중요한 부분이다. 카드를 한 번 뽑고 그 카드가 나타내는 종류 이외의 종류를 가지는 카드를 뽑을 때까지 카드를 뽑는다. 이때 카드가 중복이 될 수 있다. 왜냐하면 경우의 수는 복원 추출이기 때문이다. 복원 추출은 카드를 빼서 확인한 후 다시 카드를 넣어서 뽑는 것을 말한다. 그러므로 확률적으로 그 다음 카드가 뽑힐 확률에 영향을 주지 않는다. 이러한 방식으로 카드를 뽑았다.
#
# 처음 알고리즘은 위의 코드에 주석 처리된 부분에서 보이는 것처럼 일단 하나의 카드를 random 모듈을 이용하여 선택하고 for문을 이용하여 나머지 세 장의 카드를 뽑는다. 뽑을 때마다 selectCard라는 빈 리스트에 추가를 해주었다. 그리고 이 selectCard의 원소의 개수를 나타내 주는 selectCard_count를 이용하였다. 두 번째 카드를 뽑을 때는 첫 번째 카드와 마찬가지로 random 모듈로 카드를 뽑고 만약 이 카드가 첫 번째 카드의 모양과 같으면서 selectCard의 리스트 안에 원소가 1개만 있을 경우 두 번째 카드가 추가되도록 하였다. 문제는 세 번째 카드에서부터이다. 세 번째 카드를 뽑을 때, 만약 세 번째 카드가 문제의 조건에 부합하도록 첫 번째 카드의 모양과 두 번째 카드의 모양과 다르다면 selectCard에 추가를 해주고 selectCard_count의 값을 1 증가 시켜주면 된다. 하지만 만약 부합하지 않는, 모양이 겹칠 경우 else의 조건으로 반복문의 맨 처음으로 가게 된다. 이렇게 되면 정상적으로 조건을 만족한 두 번째 카드도 다시 초기화를 시켜주게 된다. 이런 방법을 고수 한하면 break를 적절한 위치에 쓰면 되는데 그렇게 되면 하드코딩으로 너무나 복잡하게 되고 좋지 않은 코드가 된다.
#
# 그래서 다른 방법으로 고안해보았다. 어차피 카드의 종류는 Spade, Clover, Heart, Diamond 이렇게 네 종류만 있다. selectCard에 이 네 종류가 들어가게 되면 문제의 조건에 부합하게 되는 것이다. 그렇기에 이 네 종류가 들어가게 되면 반복문을 탈출하도록 만들면 된다. 우선, bool형을 이용하였다. boolSelect라는 bool형 리스트에 4개의 원소에 모두 False를 설정해주었다. 각각의 원소는 리스트의 0번째는 Spade, 1번째는 Clover, 2번째는 Heart, 4번째는 Diamond의 카드라고 생각해준다. 그리고 아까 처음 짜보았던 알고리즘과 같이 뽑힌 카드는 selectCard 리스트에 추가해준다. 좀있다가 설명하겠지만 이 selectCard의 원소를 출력해주기 위해선 selectCard의 원소를 초기화 시켜주어야 한다. 이를 위해선 boolSelect의 리스트에 원소의 개수를 확인해주어 selectCard 리스트에 추가해주어야 한다. 마지막으로 필요한 변수는 전체 시행 횟수를 나타내는 total_count이다.
#
# 먼저, 무한 루프를 돌려준다. 앞에서 말했듯이 무한 루프의 탈출 조건은 boolSelect 리스트의 원소가 모두 True가 될 때이다. 카드를 뽑을 코드를 짠다. 카드는 52장 중에서 랜덤으로 하나가 선택되어야 하므로
#
# *
# randomSelect = random.randrange(len(Trump))
# *
#
# 라는 변수를 선언하여 인덱스 값에 접근하여 모양을 추출해준다. while문의 두 번째 줄에는 total_count를 세준다. 여기 위치에 있으면 카드를 하나 뽑을 때마다 계속해서 세주는 효과가 있으므로 코드의 중복을 없애줄 수 있다. 그 다음 문장은 탈출 조건이다. 탈출 조건은 boolSelect의 각각의 원소가 True이면 break를 통해 탈출해준다. 그 다음 줄부터는 카드의 모양에 따라서 알고리즘을 시행해준다. 만약 뽑은 카드가 "Spade"이고 boolSelect의 첫 번째 원소("Spade"의 원소를 나타내주므로)가 False라면 selectCard에 뽑은 카드를 추가해주면서 동시에 boolSelect의 원소도 True로 바꾸어 준다. 이렇게 되면 나중에 다시 반복문을 시행했을 때, 뽑은 카드가 "Spade"이라면 이미 boolSelect 리스트 안에 "Spade"의 위치가 True이므로 다시 카드를 뽑아주어야 한다.
#
# 이런 방법을 반복하여 뽑고 탈출 조건을 만족하면 selectCard에 있는 원소들과 전체 시행 횟수를 출력해준다.

# %% [markdown]
# # 문제 3번.
#
# (패턴 인식: 연속된 네 개의 동일 숫자) 어떤 리스트가 동일한 네 숫자를 연속으로 갖고 있는지를 검사하는 함수를 작성하시오. 함수 헤더는 다음과 같다.
#
# *
# def isConsecutiveFour(values):
# *
#
# 사용자로부터 일련의 정수들을 입력받고, 동일한 네 숫자를 연속으로 갖고 있는지를 검사하는 테스트 프로그램을 작성하시오.

# %%
def isConsecutiveFour(values):
    cnt = 0 # 연속된 숫자를 확인하기 위해 세주는 변수
    for x in range(len(values)): # values 리스트 길이만큼
        if x+1 == len(values): # 연속된 숫자를 확인하기 때문에 리스트 길이가 초과되면 안되므로
                break          # 만약 뒤에 숫자가 초과하면 함수 종료
        if values[x] == values[x + 1]: # 만약 연속된 숫자가 동일하다면
            cnt += 1                 # cnt의 값을 1 증가
 
    if cnt == 3: # 만약 연속된 숫자가 4개라면 두 개씩 비교하므로 3이 카운트 된다
        print("연속입니다")
    else:
        print("불연속입니다")
        
user_lst = input("10개의 숫자를 입력하세요:");
change_user_string_lst = user_lst.split() # 입력된 문자열을 split으로 문자열 리스트로 변환
change_user_digit_lst = list(map(int, change_user_string_lst)) # 문자열 리스트를 정수형 리스트로 변환

isConsecutiveFour(change_user_digit_lst)
# Out:
# 10개의 숫자를 입력하세요:32 21 92 77 77 77 77 49 64 2
# 연속입니다

# %% [markdown]
# ## 코드에 대한 설명
#
# 이 문제는 리스트의 원소 중 연속된 4개의 원소를 가지는지 검사하는 코드를 짜는 것이다. 만약 연속된 숫자가 네 개라고 가정하고 다음과 같은 숫자가 있다하면, a1, a2, a3, a4. 맨 처음 a1라는 숫자와 a2의 숫자를 먼저 비교한다. 만약 같다면 연속된 숫자를 확인했다는 카운트를 하나 증가해주고, 다음 a2와 a3와 비교한다. 역시나 같다면 카운트를 해준다. 마지막으로 a3와 a4를 비교해주고 같다면 카운트를 해준다. 만약 a4 다음의 숫자와 비교했을 때 같게 되면 연속된 숫자가 4개가 아니므로 카운트를 해주지 않는다. 즉, 카운트의 숫자가 3개이어야만 연속된 숫자 4개를 가지고 있다고 할 수 있다.

# %% [markdown]
# # 문제 4번.
#
# (행렬의 주대각선 합하기) 다음 헤더를 사용하여 정수로 이루어진 n x n 행렬의 주대각선에 포함된 모든 숫자의 합을 구하는 함수를 작성하시오.
#
# *
# def sumMajorDiagonal(m):
# *
#
# 주대각선이란 정방행렬의 왼쪽 위 모서리에서 오른쪽 아래 모서리를 가로지르는 대각선을 말한다. 4 x 4 행렬을 읽고 주대각선에 있는 모든 원소의 합계를 출력하는 프로그램을 작성하시오.

# %%
matrix = [] # n x n 행렬

# 사용자로부터 n의 값을 입력
n = eval(input("n의 값을 입력하세요:"))

# n x n 리스트의 원소 할당
for i in range(n):
    print(n, "x", n, "행렬의", i + 1, "번의 행에 대한 원소를 입력하세요:", end = "")
    row = list(map(float, input().split())) # 입력받은 문자열을 실수형 리스트로 바꾼다
    matrix.append(row) # matrix에 원소를 하나씩 추가해준다
    
# 주대각선에 있는 모든 원소의 합계 출력
def sumMajorDiagonal(m):
    totalDiagonal = 0 # 주대각선에 포함된 원소의 합계
    for i in range(len(m)):
        totalDiagonal += m[i][i] # 주대각선의 원소만 더하므로
        
    print("주대각선에 포함된 원소의 합계는", totalDiagonal, "입니다.")

sumMajorDiagonal(matrix)
# Out:
# n의 값을 입력하세요:4
# 4 x 4 행렬의 1 번의 행에 대한 원소를 입력하세요:1 2 3 4
# 4 x 4 행렬의 2 번의 행에 대한 원소를 입력하세요:5 6.5 7 8
# 4 x 4 행렬의 3 번의 행에 대한 원소를 입력하세요:9 10 11 12
# 4 x 4 행렬의 4 번의 행에 대한 원소를 입력하세요:13 14 15 16
# 주대각선에 포함된 원소의 합계는 34.5 입니다.

# %% [markdown]
# ## 코드에 대한 설명
#
# 문제 4번은 사용자로부터 n의 값을 입력 받아 n의 크기만큼의 정사각형 행렬을 만들어 대각선의 원소들만 더해주는 문제이다. 먼저 n x n 행렬에서 n의 값을 사용자로부터 받는다. 그 다음 문제에서 나온 것과 같이 각 행에 대한 원소의 값들을 입력 받는다. 그러므로 리스트 형태로 원소를 할당받아서 각각 1행부터 n행까지 초기화 시켜준다. 원소를 리스트로 만드는 방법은 우선 입력받은 문자열을 split 메소드를 이용하여 문자열 리스트로 바꾸어 주고 map 메소드를 이용하여 실수형 리스트로 바꾸어 준다. 원소가 실수형일 수도 있기에 float으로 만들어주었다. 틀을 만든 다음 sumMajorDiagonal 함수의 매개변수로 위에서 만들어준 행렬을 넣어준다. 제시된 문제에서 구하고자 하는 것은 주대각선의 원소의 합계이므로 행과 열의 인덱스 값이 같은 것만 더해주면 된다.

# %% [markdown]
# # 문제 5번.
#
# (대수학: 행렬의 곱) 두 행렬을 곱하는 함수를 작성하시오. 함수의 헤더는 다음과 같다.
#
# *
# def multiplyMatrix(a, b):
# *
#
# 행렬 a와 행렬 b를 곱하기 위해서, 행렬 a의 열의 개수와 행렬 b의 행의 개수가 같아야 하고 두 행렬의 원소는 동일한 또는 호환 가능한 데이터 타입이어야 한다. c를 행렬 곱의 결과라고 하자. 행렬 a의 열의 크기는 n이라고 가정한다. 각 원소 cij는 ai1 * b1j + ai2 * b2j + ... + ain * bnj 이다. 예를 들어 3 x 3 행렬 a와 b에 대한 c는 다음과 같다.
#
# ![image.png](attachment:image.png)
#
# 단, cij = ai1 * b1j + ai2 * b2j + ai3 * b3j 이다.
#
# 사용자로부터 두 행렬을 입력받고 두 행렬의 곱을 출력하는 예제 프로그램을 작성하시오.

# %%
# 몇 차원 리스트를 만들지 결정하기
n = eval(input("n의 값을 입력하세요:"))

# 행렬 1의 리스트 원소 할당하기 전에 일차원 정수형 리스트 만들기
print("행렬 1을 입력하세요:", end = "")
rowFirst = list(map(float, input().split()))
        
# 행렬 1의 리스트 원소 할당하기
# 먼저 빈 리스트 만들기(n x n 행렬)
matrixFirst = []
for row in range(n):
    matrixFirst.append([])
    for col in range(n):
        matrixFirst[row].append([]) 

k = 0 # rowFirst의 인덱스 변수
# matrixFirst의 빈 리스트 값 할당하기
for i in range(n):
    for j in range(n):
        if matrixFirst[i][j] == []:
            matrixFirst[i][j] = rowFirst[k]
        k += 1

# 행렬 2의 리스트 원소 할당하기 전에 일차원 정수형 리스트 만들기
print("행렬 2을 입력하세요:", end = "")
rowSecond = list(map(float, input().split()))
        
# 행렬 2의 리스트 원소 할당하기
# 먼저 빈 리스트 만들기(n x n 행렬)
matrixSecond = []
for row in range(n):
    matrixSecond.append([])
    for col in range(n):
        matrixSecond[row].append([]) 
    
k = 0 # rowSecond의 인덱스 변수
# matrixSecond의 빈 리스트 값 할당하기
for i in range(n):
    for j in range(n):
        if matrixSecond[i][j] == []:
            matrixSecond[i][j] = rowSecond[k]
        k += 1

print()
# 두 행렬의 곱을 나타내는 함수
def multiplyMatrix(a, b):
    matrixThird = [] # 계산 결과를 나타내는 리스트
    tot = 0 # 원소끼리의 곱의 합(각 행마다의 원소를 지정)
    # matrixThird의 빈 리스트 값 할당하기
    for row in range(n): # 행은 n의 길이만큼
        matrixThird.append([]) # 각 행마다 빈 리스트 추가
        for col in range(n): # 열은 n의 길이만큼
            # 문제에서 나오는 공식 사용
            for i in range(n): # i가 n의 값에 따라서 증가함
                tot += a[row][i] * b[i][col]
            matrixThird[row].append(format(tot, ".1f")) # 각 행마다 tot의 값을 추가, 소수점 첫 째자리까지만
            tot = 0 # 다시 tot을 초기화해야 다음 열의 값을 넣어 줄 수 있다
            
    # matrixThird 리스트 출력하기
    print("결과 리스트")
    for row in range(len(matrixThird)):
        print("(", end = " ")
        for col in range(len(matrixThird)):
            print(matrixThird[row][col], end = " ")
        print(")")

multiplyMatrix(matrixFirst, matrixSecond)
# Out:
# n의 값을 입력하세요:2
# 행렬 1을 입력하세요:1 2 3 4
# 행렬 2을 입력하세요:1 2 3 4
#
# 결과 리스트
# ( 7.0 10.0 )
# ( 15.0 22.0 )

# %% [markdown]
# ## 코드에 대한 설명
#
# 문제 5번도 문제 2번에 버금갈 정도로 상당히 애먹은 문제였다. 이 문제의 가장 어려웠던 부분은 크게 두 가지이다. 첫 번째는 문제에서 제시된 행렬의 입력 값을 n x n행렬의 리스트에 초기화하는 방법이다. 우선 나는 입력한 행렬을 하나의 큰 일차원 리스트로 만들었다. 그래서 이 일차원 리스트를 가지고 n차원 리스트의 값을 초기화 시켜주었다.
#
# 먼저 첫 번째 n차원 리스트를 초기화를 해야한다. 교수님께서 수업에서 가르쳐주신 다차원 리스트 만들기를 이용했다. 다음과 같이 만들면 된다.
#
# ```
# matrixFirst = []
# for row in range(n):
#     matrixFirst.append([])
#     for col in range(n):
#         matrixFirst[row].append([])
# ```
#
# 위와 같은 코드를 통해 n차원의 빈 리스트가 생성이 되었다. 이제 이 빈 리스트의 원소들을 채워야 한다. 여기서 나는 너무 어렵게 생각한 나머지 아까 처음에 받았던 하나의 일차원 리스트를 n으로 나누어서 그 원소만큼만 할당해주려 하였다. 예를 들어, 3차원 리스트를 만들고자 하는데, 일차원 리스트에는 현재 9개의 값이 있다. 이를 3으로 끊어서 즉, 원소 0, 1, 2의 값을 3차원 리스트 1행에 넣어주고 원소 3, 4, 5의 값을 3차원 리스트 2행에 넣어주는 식으로 하려고 했다. 하지만 이 끊어서 넣는 방식이 생각보다 어려워서 다른 방법을 고안해보았다. 고안해본 결과 다음과 같이 k라는 변수 하나만 생성해주면 쉽게 할당해줄 수 있었다.
#
# ```
# k = 0
# for i in range(n):
#     for j in range(n):
#         if matrixFirst[i][j] == []:
#             matrixFirst[i][j] = rowFirst[k]
#         k += 1
# ```
#
# 이제 두 번째 n차원 리스트 역시도 위와 같은 방법으로 빈 리스트로 만들어서 처음 입력된 값으로 할당해준다.
#
# 가장 어려웠던 부분 중에 두 번째가 바로 공식을 사용하는 것이다. 제시된 문제에서는 3차원 행렬끼리의 곱을 나타내 주었지만 문제 자체가 어떤 차원이든 행렬의 곱을 해주어야 하기 때문에 공식을 잘 파악하는 것이 관건이었다. 공식의 핵심 코드는 다음과 같다.
#
# ```
# for i in range(n):
#                 tot += a[row][i] * b[i][col]
# ```
#
# 위의 tot이라는 변수는 결과 리스트의 각 행에 대한 열의 원소 값을 정해주기 위해서이다. for문을 사용한 것은 n의 값이 다차원이 될 수 있기 때문이다. 위의 공식만 빠르게 파악했다면 금방 해결할 수 있었을 것이다. 여기서 또 중요한 부분이 각 열마다 tot의 값을 결과 리스트에 저장한 뒤 다시 tot의 값을 0으로 초기화해야만 그 다음 행에 대한 열의 값들을 새로이 초기화 시켜줄 수 있다.
