# %% [markdown]
# # 문제 1번
#
# ## (게임: 덧셈 학습하기) 100 이하의 2 개 정수를 생성하고 이들 정수의 합을 사용자가 맞추도록 하는 프로그램을 작성하시오. 사용자의 입력 값이 맞는지 혹은 틀린지를 출력해야 한다. 이 프로그램은 AdditionQuiz.py 와 유사하다.

# %%
# 난수 발생을 위한 함수
import random

# 두 개의 난수 생성
num1 = random.randint(0,100)
num2 = random.randint(0,100)

# 두 정수의 합
sum = num1 + num2

# 사용자로부터 예상되는 정수의 합 입력
user_input = eval(input("정수의 합은 얼마일까요?:"))

# while 문을 이용해 사용자 입력 값과 두 정수의 합 비교 
while True:
    if user_input == sum:
        print("맞습니다.\n")
        break
    elif user_input > sum: 
        print("입력된 값이 더 큽니다.\n")
        user_input = eval(input("정수의 합은 얼마일까요(재입력)?:"))
    else:
        print("입력된 값이 더 작습니다.\n")
        user_input = eval(input("정수의 합은 얼마일까요(재입력)?:"))
# Out:
# 정수의 합은 얼마일까요?:50
# 입력된 값이 더 큽니다.
#
# 정수의 합은 얼마일까요(재입력)?:25
# 입력된 값이 더 작습니다.
#
# 정수의 합은 얼마일까요(재입력)?:38
# 입력된 값이 더 큽니다.
#
# 정수의 합은 얼마일까요(재입력)?:30
# 입력된 값이 더 작습니다.
#
# 정수의 합은 얼마일까요(재입력)?:33
# 입력된 값이 더 작습니다.
#
# 정수의 합은 얼마일까요(재입력)?:34
# 맞습니다.

# %% [markdown]
# ### 코드에 대한 설명
# ### 이 문제는 사용자가 정답을 맞출 수 있도록 계속해서 유도해주는 방법을 사용하면 된다. 그러므로 반복문을 써주면 된다. 그 전에 컴퓨터가 랜덤으로 나온 숫자를 정할 수 있도록 random함수를 import해준다. randint(a,b)를 사용하면 a이상 b이하의 값이 나온다. 그 다음 핵심인 while문의 조건문에 True나 1을 써서 무한루프를 생성해준다. 그리고 나서 if문을 이용해 사용자가 추측한 답과 정답을 비교하여 크거나 작다를 알려주며 정답을 유추할 수 있도록 해준다. 그 후 정답을 맞추게 되면 무한 루프를 탈출할 수 있도록 break를 사용한다.

# %% [markdown]
# # 문제 2번
#
# ## (미래의 요일 맞추기) 사용자가 오늘의 요일을 정수로 입력하는 프로그램을 작성하시오(예를 들어, 일요일은 0, 월요일은 1, ... , 토요일은 6). 또한 사용자로부터 오늘부터 경과한 일수를 입력하면 미래의 요일을 출력합니다.

# %%
# 사용자로부터 오늘의 요일을 입력
days = eval(input("오늘의 요일을 입력하세요:"))

# 사용자로부터 오늘부터 경과한 일수를 입력
routing = eval(input("오늘부터 경과한 일수를 입력하세요:"))

# 미래의 요일 값 정하기
future = days + routing % 7

# 사용자로부터 받은 오늘의 요일을 문자열로 바꾸는 함수
def change_days(num):
    if num == 0:
        return "일요일"
    elif days == 1:
        return "월요일"
    elif num == 2:
        return "화요일"
    elif num == 3:
        return "수요일"
    elif num == 4:
        return "목요일"
    elif num == 5:
        return "금요일"
    elif num == 6:
        return "토요일"

# 미래의 요일 출력
print("오늘은 " + change_days(days) + "이고 미래의 요일은 " + change_days(future) + "입니다.." )
# Out:
# 오늘의 요일을 입력하세요:0
# 오늘부터 경과한 일수를 입력하세요:31
# 오늘은 일요일이고 미래의 요일은 수요일입니다..

# %% [markdown]
# ### 코드에 대한 설명
# ### 미래의 요일을 맞추기 위해서 우선 요일을 문자열로 바꿔줄 필요가 있다. 따라서 값이 0일 때, 일요일을 출력하고, 값이 6일때, 토요일이 되는 함수를 만들어 주었다. 함수를 만드는 방법은 def 함수이름(매개변수): 를 이용한다. 일요일부터 토요일까지는 0부터 6까지이므로 사용자로부터 오늘부터 경과한 일수를 7로 나눈 나머지 값이 요일을 정할 수 있다. 이 값에다가 또 다른 사용자로부터 얻은 오늘의 요일을 더한 것이 미래의 요일을 결정하는 값이다. 마지막으로 미래의 요일을 출력하면 된다.

# %% [markdown]
# # 문제 3번
#
# ## (숫자 검사하기) 사용자로부터 하나의 정수를 입력받고, 그 정수가 5와 6 모두 나누어지는지, 5 또는 6으로 나누어지는지, 혹은 두 정수 모두로는 나누어지지 않지만 둘 중에 하나로만 나누어지는지를 검사하는 프로그램을 작성하시오.

# %%
# 사용자로부터 하나의 정수를 입력
num = eval(input("하나의 정수를 입력하세요:"))

# 5와 6으로 모두 나누어지는지 검사하기
print(num, "은/는 5 와 6 으로 나누어집니까?" ,bool((num % 5 == 0) and (num % 6 == 0)))

# 5또는 6으로 나누어지는지 검사하기
print(num, "은/는 5 혹은 6 으로 나누어집니까?" ,bool((num % 5 == 0) or (num % 6 == 0)))
      
# 5와 6으로 모두 나누어지지 않지만 둘 중에 하나로는 나누어지는지 검사하기
print(num, "은/는 5 혹은 6으로 나누어지지만, 둘 모두로는 나누어지지 않습니까?" ,bool((num % 5 == 0) or (num % 6 == 0) and (num % 30 != 0)))
# Out:
# 하나의 정수를 입력하세요:10
# 10 은/는 5 와 6 으로 나누어집니까? False
# 10 은/는 5 혹은 6 으로 나누어집니까? True
# 10 은/는 5 혹은 6으로 나누어지지만, 둘 모두로는 나누어지지 않습니까? True

# %% [markdown]
# ### 코드에 대한 설명
# ### 사용자로부터 얻은 하나의 정수를 5와 6으로 다양한 방법으로 나누어지는지 안나누어지는지를 알아보는 문제이다. 따라서 참인지 거짓인지 판별할 수 있는 bool함수를 이용한다. 첫 번째 질문에는 5와 6으로 모두 나누어지는지 검사하는 것이므로 %연산자를 이용, 5로 나눈 나머지가 0이면서 6으로도 나눈 나머지가 0이어야 된다. 따라서 논리 연산자 and를 사용한다. 두 번째 질문에는 5또는 6으로 나누어지므로 논리 연산자 or를 사용한다. 세 번째 질문에는 둘 중에 하나로 나누어지지만 둘 모두로는 나누어지지 않게 해야 하므로 5로 나누어지는 조건과 6으로 나누어지는 조건을 논리 연산자 or를 사용하며 동시에 5와 6 모두 나누어지지 않도록(30으로는 나누어지지 않도록) != 연산자를 이용해 논리 연산자 and를 사용한다.

# %% [markdown]
# # 문제 4번
#
# ## (대칭수) 사용자로부터 세 자리 정수를 입력받고 그 숫자가 대칭수(palindrome number)인지를 판별하는 프로그램을 작성하시오. 어떤 숫자를 오른쪽에서 왼쪽으로 읽으나 왼쪽에서 오른쪽으로 읽으나 서로 같다면, 그 숫자는 대칭수이다.

# %%
# 사용자로부터 세 자리 정수 입력
num = input("세 자리 정수를 입력하세요:")

# 입력받은 정수가 대칭수인지 아닌지 구별해서 출력
if num[0] == num[2]:
    print(num, "은/는 대칭수입니다.")
else:
    print(num, "은/는 대칭수가 아닙니다.")
# Out:
# 세 자리 정수를 입력하세요:121
# 121 은/는 대칭수입니다.

# %% [markdown]
# ### 코드에 대한 설명
# ### 이 문제는 세 자리 정수가 대칭수인지를 확인하는 것이므로 맨 앞 숫자와 맨 뒤 숫자만 같으면 대칭수이기에 세 자리 정수를 문자열로 입력받아 리스트를 이용하여, 0번째 값(즉, 맨 앞의 숫자, 실질적으로는 문자열이나 설정상 숫자)과 2번째 값(즉, 맨 뒤의 숫자, 실질적으로는 문자열이나 설정상 숫자)이 같다고 if문을 이용하여 출력해준다. 2번째 값은 -1로 써도 같은 결과가 나온다.

# %% [markdown]
# # 문제 5번
#
# ## (16진수를 10진수로 변환) 사용자로부터 16진수 문자를 입력받고, 입력 문자에 해당하는 10 진수 정수를 출력하는 프로그램을 작성하시오.

# %%
# 사용자로부터 16진수 문자 입력
char = input("16진수 문자를 입력하세요:")

# 입력받은 16진수 문자를 10진수로 변환하여 출력
# A 또는 a라는 문자를 받은 경우 10을 출력
if char == 'A' or char == 'a':
    print("10진수 값은 10입니다")
# B 또는 b라는 문자를 받은 경우 11을 출력
elif char == 'B' or char == 'b':
    print("10진수 값은 11입니다")
# C 또는 c라는 문자를 받은 경우 12를 출력
elif char == 'C' or char == 'c':
    print("10진수 값은 12입니다")
# D 또는 d라는 문자를 받은 경우 13을 출력
elif char == 'D' or char == 'd':
    print("10진수 값은 13입니다")
# E 또는 e라는 문자를 받은 경우 14를 출력
elif char == 'E' or char == 'e':
    print("10진수 값은 14입니다")
# G 또는 g라는 문자를 받은 경우 15를 출력
elif char == 'F' or char == 'f':
    print("10진수 값은 15입니다")
# 0부터 9까지는 아스키코드 변환문자가 10진수와 동일하므로 ord함수를 사용하여 출력
elif ord(char) >= 48 and ord(char) <= 57:
    print("10진수 값은", char, "입니다")
# 그 이외의 문자가 입력된 경우 잘못된 입력이라고 출력
else:
    print("잘못된 입력입니다.")
# Out:
# 16진수 문자를 입력하세요:G
# 잘못된 입력입니다.

# %% [markdown]
# ### 코드에 대한 설명
# ### 16진수는 10진수와 다르게 0부터 9까지는 10진수와 같지만 10부터 15까지는 알파벳을 사용한다. 10은 A, 11은 B, 12는 C, 13은 D, 14는 E, 15는 F이다. 따라서 if~else문을 사용하여 0부터 9까지는 ord함수를 이용, 아스키코드가 16진수와 10진수가 같다는 점을 착안하여 그 숫자를 입력 받는 경우 문자 그대로 출력하고 나머지 A부터 F까지 입력 받는 경우 16진수 형태인 각각 10부터 15까지 출력한다. 마지막에 G부터의 문자는 16진수가 아니므로 잘못된 입력으로 출력한다.
