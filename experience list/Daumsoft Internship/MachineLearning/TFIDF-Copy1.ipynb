# %%
import pandas as pd

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train = train.sample(frac=1).reset_index(drop=True)
test = test.sample(frac=1).reset_index(drop=True)

# %%
train = train.dropna()
test = test.dropna()

# %%
train.shape
# Out:
# (23384, 2)

# %%
test.shape
# Out:
# (5849, 2)

# %%
X_train_corpus = []
for words in train['x']:
    sentence = ""
    for word in words.split(","):
        sentence += word + " "
    sentence = sentence[:len(sentence)-1]

    X_train_corpus.append(sentence)

# %%
X_test_corpus = []
for words in test['x']:
    sentence = ""
    for word in words.split(","):
        sentence += word + " "
    sentence = sentence[:len(sentence)-1]

    X_test_corpus.append(sentence)

# %%
X_train_corpus
# Out:
# ['배송 편 재구매 펄 색감좋으네요',
#  '평소 아벤느 라로슈포제 꺼 스킨 제품 여드 민감성 피부 용',
#  '색상 케이스 압도 맘',
#  '옷 향수 대용 예전 향 유지력 편',
#  '생각 배송 일만 오래 상품 재구매 쌤플이',
#  '양',
#  '색상 맘',
#  '이향 넘 남 향 때적극',
#  '색 맘',
#  '향',
#  '배송 가격 색상 완전 색상 네요 라벤더 완존 각질 쪼금 부각 한데 이것 쪼금 데이 션 삿어요 안쪽 핑크 사진 어반 정글',
#  '애굣살 핑쿠색 색 좋음요',
#  '펄감 색상 핑크 색',
#  '제품 롯데 닷컴 샘플 용량 가격 제품 배송',
#  '넘이뻐요',
#  '가격 곳 정품 샘플 조금',
#  '향 케이스',
#  '백화점 입자 향도 디잔 집 완전 조아',
#  '밤',
#  '오프라인 가격 저렴 온라인 오프라인 때 샘플 상품',
#  '이름값 맘 디쟌',
#  '발림',
#  '언젠가 립스틱 욕심 색 디자인 마음 듬',
#  '겉보기 진저 발색 눈 색 기분 때 가루 날림 편 진저 꼬냑 팔레트 데일리',
#  '가격 구입 양',
#  '마음 색상 샤넬 진리',
#  '인생템 블랙 브라운 다음 버건디 컬링력',
#  '상품 배송 용량',
#  '건성 피부 보습력 신경 편 제품 중 보습력 편이 보습력 향기 신경 제품 향기 넘 만족',
#  '제품 지에스 피부 표면 쫀쫀 해지 느 느낌',
#  '미샤 매장 피부 번째',
#  '향 배송',
#  '이번 여름 넘 화이트 라인',
#  '좋은 상품 저렴히 미백 기능',
#  '가격 싼편 배송 감 양 진정 효과 재구매 의사 지경',
#  '때 샘플 샘플 아이 젤 피부 다음 제품 가격',
#  '사용 중 수 언제 붙 점을 사용 중',
#  '색깔 광택 값',
#  '느낌 생각 보담 흡수력 분정 지금 흡수 진뜩진뜩한 느낌',
#  '배송 양 한참 때',
#  '로드샵 몇차레 용량큰 거사 꿀 트러블 없 조아',
#  '손 여름 핸드 크림 바이오 더마 향 보습 재구매 의사',
#  '샘플두 넘 효과 가격',
#  '비욘드 바디 제품 짱인거 세럼 오일 향 생각 용량 이번 용량',
#  '가격',
#  '에 랑 제품 이것 가격 백화점 색상 노란색 느낌',
#  '질감 마음 케이스 추천',
#  '색 레드 오렌지 빛 레드',
#  '배송 굿 발림성 굿 쉐딩 은근 티 안나 거 색상 진짜 발림성 최고',
#  '발림성 컬러 느낌 파운데이션',
#  '제품 바닐라 코 제품 중 프라이머 클래식 발림성 피부',
#  '화장 용량 맘',
#  '의향 있읍니 양 의향',
#  '록시땅 아몬드 향 보습력',
#  '기회 적립금 할인 사은품 실속 다용도 대 중 소 사이즈 실버백 패키지 가량 클리어 로션 에센스 감동',
#  '가격대비 택배 좋 사용감',
#  '토너',
#  '배송 분 제품',
#  '향 가격 정도 제품',
#  '톤업 생각 양 편',
#  '예전 향',
#  '가격 포장 배송 하루 만 부모님 생신',
#  '색깔 넘맘에',
#  '배송',
#  '사진 이랑 색 냄새 이상 한편 돈 아깝지 힝',
#  '전 겨울 진정 효과 자극',
#  '배송 가격',
#  '밀착력 색상 무난',
#  '여름 수분 크림 인터넷 생각 양이좀',
#  '이번 대용량 샘플 기획 구성 샘플 대용량 에센스 기초 제품 샘플 위주 기획 구성 제품 자체 클렌징 제품 위주 샘플 용량',
#  '색상 넘',
#  '용량 미리 수분 에센스 유분기 에센스 별로',
#  '양상 처음 수분 피부',
#  '크기 향도 괜찬고 가격 좋으네요',
#  '향',
#  '배송',
#  '겟 잇 뷰티 색상 보라색 브라운 느낌',
#  '모양',
#  '동안 아이크림 영양 크림 신경 순간 영양 크림 나이 생각 기존 제품 바닥 설화수 한번 밀착감 기분',
#  '바 스텔톤 봄 느낌 조음',
#  '커버력 편 건성 중복합 피부 뽀송해 보이 느낌 각질 부각 모공끼임 성분 해서 가격 합리적 향 호불호 갈릴꺼 갠평 비추 합리적 가격 웜톤 홍조 추천',
#  '마음 향도',
#  '가격',
#  '색 처음 자주 기분 때',
#  '한번 향 계속 가격 로즈향 향 샤워시 거품 여 록시땅',
#  '색 용기 느낌 내용물 한병다',
#  '예전 제품 필요 향기',
#  '가격 제품 케이스 스킨푸드 제품 내용물 말 크림 리치 건성 피부 전 중복 합성 오래 향 만족',
#  '추가 구성 아이크림 가음 라인 미백 스킨 에멀젼 채음 라인 처음 향 기간 동안 품질 택배 물품 많 기간 택배 기사',
#  '상품 디자인 샘플 써비스 마음',
#  '케이스 디자인 샘플 컨실러',
#  '용량 느낌',
#  '랑콤 립스틱 처음 입술 입술 색상 글로 시하 입술 부담 선물',
#  '엄마',
#  '양 유명 한거',
#  '배송 주말 상품 옥수수 완충 제랑 제조 일자 한달조금 이니스프리 제조 일자 최근거 크리스마스 쿠폰 에코 내추럴 비비 크림',
#  '만족 저녁 아침 때 쫀쫀하 느낌',
#  '지속력 밀착 가격 정도 거 색도 오',
#  '크리니크 안티블레미쉬 로션 모이스춰 로션 모이스춰 크기 때 모이스쳐 개쓰는듯 가격대비 크기 짱이 진짜 오래 듯 여드름 지성 느낌',
#  '향 발림성',
#  '색상',
#  '색깔 느므느므',
#  '삼일 정거 용량 돔 때',
#  '크리니크 에센스 수분 크림 선물 구매 선물 분 구매 쿠폰 할인',
#  '스승 날 선물 포장 상태',
#  '번째 구매 배송 산거 여름 이거 메이크업 내림',
#  '배송 파우치 맘 며칠 거 트러블성 지성 피부 비오템 수분 크림 클리니크 수분 크림 상품평 끈적임 없 사은품 턴어라운드 피부',
#  '색상 여러가지 처음 근대 아이라이너 용',
#  '미사용 샘플 사용 생각 양',
#  '고가 양',
#  '한상 쓰선거고 겨울 라이트 조다 리치 좋 사서 사용 중 곳 조',
#  '커버력 피부 느낌 정도 밀림 지속성',
#  '색상 동양인 색상 물광 효과',
#  '크림 크림',
#  '라메르 립밥 막 느낌 촉 겉 막 느낌',
#  '예전 이번 양',
#  '사용 생각 양',
#  '향기 넘',
#  '향기',
#  '배송',
#  '제품 때',
#  '넘 양 넘',
#  '색이넘넘',
#  '전 이번 요아이 대 만족 용량 타입 패스 자외선 차단 아쉬움 정도',
#  '딸아이 케이스',
#  '수분 크림 시세이도',
#  '욤 부담',
#  '향 색상 맘 가격 향 색상 맘 가격 향 색상 맘 가격 마켓 안드로이드 앱 작성',
#  '라벤다 향 구 용량',
#  '흡수 성도 번들거림없',
#  '때 제품 장만',
#  '번째 피부 용량 정도 제품 제품 펌프식',
#  '배송 커버력 제품 리필',
#  '피부 지성 세럼 오일 중간 단계 겨울철',
#  '전 지속력 패키지 종이곽 가격 색상 구매',
#  '제품 발림성 지속력 색인데 계속',
#  '수분 피부 거 배송',
#  '배송 연휴 이틀 배송 용량 생각 바디 제품 보습',
#  '연령대 피부 타입 건성 지성 복합성 복합성 제품 사용 횟수 기간 제조 일자 도움 사용 후기 편 옥션 안드로이드 앱 작성',
#  '처음 제품 샘플 보고 마켓 안드로이드 앱 작성',
#  '장미향',
#  '베네피트 블루 넘',
#  '케이스 색깔 맘 입술 각질 부각 각질 관리 후',
#  '한데 제품양',
#  '재구매',
#  '물건 상자 유리 병 얼굴 질꺼 기분 향 샘플 용량 오래 쓸꺼',
#  '팔레트 색깔',
#  '예전 사이트 때 용량 위클릭 안 제품 용량 넘',
#  '사용감 향기 제품',
#  '평소 거 커버력 편이 란제리 트 뽀 리퀴드 후 마루 리고 컨실러 추천 도장',
#  '사용 양',
#  '완전 가격 요녀석 덕분 겨울 소재 향 기능 전',
#  '향 핸드백',
#  '여름 로션 대신 용량',
#  '향 복합성 일반 제품 중 유분기',
#  '사용감',
#  '발림성 커버력',
#  '디올 색',
#  '백화점 샘플',
#  '오래써 효과 용량 배송도 장미향 잡티',
#  '가격 했지 백화점 상품 다행 색깔 생각 웜톤',
#  '아이라이너 토니모리 가격 양 발색력',
#  '향 라일락 듯요 쬐금 샘플 포장',
#  '정품 매장 요청 사항 생산일 제품 제품 샘플 색상 매장 테스트 거 다크 서클 코렉터 가격 눈가',
#  '양 향 용기',
#  '냄새 해프게 가격 제품 자체',
#  '색 촉촉함',
#  '배송 맘 제품 제품 걱정 가격 기분',
#  '친구꺼 향 지속력 발색 예빠요 만족 레드립 굿',
#  '용기 용량 예전 던게 용량',
#  '디자인 별로지 성능 굿 이예 브러쉬 감 고무 재질 색상 붓 특성 상 끝',
#  '가격 저렴 성분',
#  '트러블 피부',
#  '향기',
#  '향 피부',
#  '번째 구입 커버 만족 배송 전반적 만족',
#  '친구 추천 사용감 지성 피부 앞',
#  '발림 향',
#  '발색력 냄새 배송 맘',
#  '박스 제품 포장 신경',
#  '용량 친구',
#  '촉촉 색감 넘 만족 색상 재구매 예정',
#  '크림 향',
#  '엄마 쿠폰',
#  '향',
#  '색이 않 마구 마구 새거인데 뚜껑 케이스 의문 궁금 색깔',
#  '배송 손등 테스팅 타입 이라 색상 아무색 어울릴거 엄마 싶으다 세트 지속력 일반 클렌징 오일 워터 프루프 워터 프루프 아이 리무버 지속력 짱인거 넘 맘 내일 데이트 때',
#  '색상 양 솔 다이소 추천 부러쉬',
#  '흡수',
#  '배송 가격 컬러',
#  '기대 이상 색상 보람 색깔 넘',
#  '이건일 양이정 가격 큼요',
#  '배송 편 향 손등 물광 효과 마켓 안드로이드 앱 작성',
#  '배송 색',
#  '사이트 상품 동시 배송 요청 상품 하루',
#  '라이트 골드 삿 앞면 아트 무지 디자인 면 클리오 화이트 골드',
#  '피부 지금 정도 피부 느낌 이에요 가격 달팽이 크림 외관 원주 썻다고',
#  '배송 유명 해서 마스카라 만 하면 리무버 로 깨끗 눈',
#  '생강 냄새 겨울 냄새 무향 제품 부작용 없',
#  '향',
#  '재구매 코랄 중',
#  '발림성',
#  '컬러 말린 장미 컬러 중 부담 손',
#  '느낌 마음',
#  '언니 삿 맘',
#  '피부 청 감두 향',
#  '곳 산것 배송두 건성 요즘 얼굴 난리 간만 양',
#  '냄새 제품',
#  '향',
#  '색깔 펄 블링 눈 연출',
#  '양 사면',
#  '커버력 생각 양',
#  '핑크 골든 핑크 브라운 이번 색감 배송',
#  '쌤플로 사용 펄 광택 발림성 갈색 병',
#  '상품평 사용 중입이다 시간 피부톤 비타 레이저 사용 본결 점 양 부분 정도 밖 눈',
#  '색',
#  '제품 유분도 수분 적당 알러 지성 피부라 제품 피부 자극 피부 촉촉하개',
#  '느낌 수분',
#  '오프라인 용량 보습력 마켓 안드로이드 앱 작성',
#  '용량 팁 내용물 한데 색 리퀴드 섀딩 닥터 자르트 더페 아임 미미',
#  '크리니크 예전 오랫만 느낌 용량 가격',
#  '리무버 용량',
#  '연령대 피부 타입 건성 지성 복합성 제품 사용 횟수 기간 제조 일자 도움 사용 후기 반값 할인 추가 할인 옥션 안드로이드 앱 작성',
#  '뭉침없 눈썹 마스카라 디자인 품질 마은',
#  '문릿 색상 반값 벨벳 느낌 진짜 각질 부각 뽀송 색상 진짜 찰떡 외관',
#  '촉촉 여름 스킨 병이 흠',
#  '배송 오프라인 샵 눈 상품 가격 품질 복합성 수분 부족 부분적 악건성 피부 타입 피부든촉촉 안정감 제품',
#  '피부 느낌 부르럽고 좋아하셧 어머니 사드렸느넫 스킨 처럼 용량',
#  '케이스 넘이쁜거 실물 보고 더맘에 색구성 안쓰게될색 소장',
#  '엄마',
#  '향기 색',
#  '제조 월일 최근 것이',
#  '생각 샘플',
#  '유분기 커버력 별로 색상 그닥 가격 피부결 유분기 개인 취향 겠지 개인적',
#  '마무리감 퍼프 솔 별',
#  '케이스 외부 거울 디자인',
#  '제품 가격 제품 품질 배송 속도',
#  '가격 겨울 거같아여 앞 거에 파세',
#  '조아',
#  '유수분 공급',
#  '색도 배송',
#  '양 샘플 기대 기초 라인 배송 품질 만족',
#  '처음 때 가루 때 산것 진거 용량 점',
#  '처음 때 입술 물틴트제형 감 립밤',
#  '여름 커버 제품 가격 배송',
#  '친구 부르조아 부르조아 부르조아 꺼 진한 편 요고 뽀샤시 하면 서두 맘 용량 오래',
#  '비추천 부하 얀편',
#  '블러쉬 초보 자라 색상 마스터 컨투어 블러쉬 데이션 쉐딩 구성 초보자 추천 색상 쉐딩 느낌 색 색상 마음 _',
#  '오해영 예지원 색깔',
#  '색상 제품',
#  '라네즈 베이직 종 맘 스킨 단계 건성 느낌 에멀젼 스킨 맘 스킨 로션 스킨양 로션 양보',
#  '여성 여성 디자인 팩트 피부',
#  '선물 포장 맘',
#  '뷰러없 기가 양 모르겟지 진짜 마스카라 귀중품 향도 컬링 워터 프루프',
#  '귤색 발색 진하네여',
#  '사은품 완전 로즈워터 기본템 파 세용',
#  '화장품 배송 가격 마음',
#  '가격 디자인 측면 사용 후 수분감',
#  '색상 엄마',
#  '양',
#  '제품 리뉴얼 지성 제품 향 배송 총알',
#  '발색 넘',
#  '정망 악건성 향도 수분 크림 디자인 디자인 맘에',
#  '짱짱 얼굴 잡티',
#  '액상 손등 볼때 베이지 색 핑크 색도 색 후 색 펴발리 밀착감 맘 촉촉함 가격대비 좋은 상품',
#  '조으네요 묶음 배송 묶음 배송',
#  '갈색 병 에스티로더 사은품 짱 사용감 넘',
#  '향',
#  '매장 초록색 패키지 그레이 톤 점막 채지워지 아이라이너 여기꺼 배송 쇼핑',
#  '클리오 립스틱 잘안 색상 곳 배송두',
#  '선물 배송 색깔 포장 완전',
#  '배송 용량 가격 굳굳 이번 향 겟어요',
#  '느낌',
#  '각질 수분감 워터 타입 토너 양 근데향 스킨 냄새',
#  '사용감',
#  '색 가격대비 최고 용량 눈밑이 기분',
#  '진짜 대박 물건 웜톤 쿨톤 완전 색상 재구매 의사 향기 오렌지 향 때 화장품 냄새 정말 정말',
#  '연령대 피부 타입 건성 지성 복합성 제품 사용 횟수 기간 제조 일자 월제조면 최근거 도움 사용 후기 흡수력 이세 써 당김',
#  '제품 제품 자극',
#  '훼이셜 토너 사용 촉촉 맘',
#  '품질 양 진짜',
#  '연령대 피부 타입 건성 지성 복합성 제품 사용 횟수 기간 제조 일자 도움 사용 후기 파데 맘 가격 입소문 완전 여름 날거 옥션 안드로이드 앱 작성',
#  '연령대 피부 타입 건성 지성 복합성 제품 사용 횟수 기간 제조 일자 도움 사용 후기 엄마 쓰시더거 케이스 이번 품질 가격 옥션 안드로이드 앱 작성',
#  '소문 최저 가로 포장 마자 겔랑 특유 향 특유 질감 수정 선택',
#  '색 제품',
#  '다써가꾸 포장 넘 영',
#  '이니스프리 자극적 이이 자주 사용 제품 트러블 유발 사용감 튜브 타입 용량 도톨도톨한 여드름 트러블 단시간 일주일 정도 트러블',
#  '가격 배송',
#  '용량 편 향 성준 로션',
#  '완전 배송 안내 컬러',
#  '크림 다음날 배송 우체국 택배 하루 만 배송 사은품 크림 진짜 오일 수분 수분 크림 순해 양 나중 재구매 냄새',
#  '제품 제품 피부 느낌 수분 크림 가격 배송 과대 포장',
#  '제품 가격 건성 피부 흡수',
#  '신경 때 얼굴 트러블 난리 적응 건 향 에센스 에센스 향때문 스킨 배송 주말 정도',
#  '색 가루 날림 좀',
#  '립스틱 색상',
#  '비비써 는데 보라색 비비가 잡티 짐 굿',
#  '베리 모이스처',
#  '입자 진정 수분 최고',
#  '기존 프라이머 차 댓겔 핑크 빛 프라이머 프라이머 역활 향 디쟌',
#  '색상 배송',
#  '블링 발색 지속력',
#  '짱짱 맘',
#  '색상',
#  '제품 용량 사용감',
#  '전날 다음날 완전 믿음감 앞 색 향 느낌 땀 여름 효과적',
#  '길이 디자인',
#  '입술',
#  '용량 루스 파우더',
#  '예전 먼저 보고 친구 선물 구매 키엘 모이스처라이저 키엘 제품 디자인 제품 자체 마음 종류 집 브랜드 피부 든 잘맞는거',
#  '시중 할인 가격 제품 이것 겠어요',
#  '선물 포장 만족',
#  '냄새 괜찬구 모양 쓰 진안',
#  '자극',
#  '케이스 냄새 발림 완전 정품 스티커 지금 판매 중단 진짜 원도 짜리 가격',
#  '임블리 화장법 영상 피부 파운데이션 시간 하이라이트 향기 좋으네요 고가 화장품 임블리 화장품',
#  '색상 맘',
#  '지속력 착색 색 뚜껑 부분',
#  '향 기분 전환 배 송도 편 비욘드 제품',
#  '종전 눈썹 틴트라 제품 색조 제품 처음 후 모습 색상 펜슬 흑갈색 그레이 브라운 선택 마켓 안드로이드 앱 작성',
#  '때',
#  '가격 제품',
#  '사용 느낌 전체적 배송 점',
#  '슈에무라 색이 봄철 제품 최고',
#  '캄사',
#  '구입 햇어요',
#  '제품 바디 로션 중 최고 듯요 향 양 매장 천원 유통 기한',
#  '색상',
#  '틴트 립스틱 도전 햇는데 대체적 전 피부 핑크 코랄 입술 전체 틴트 안쪽 색상 타입',
#  '엄마 생일 선물 샘플이없지 가격 넘 배송',
#  '상품 디자인 느낌 좋으네요 피부 질 용량 배송 속도 방문 판매 가격 물건 데 차이 인터파크 후회',
#  '전반적 냄새',
#  '디땅 립스틱 색',
#  '발림성 향 넘 스타일',
#  '스킨 보고 셋트 구매',
#  '연령대 피부 타입 건성 지성 복합성 제품 사용 횟수 기간 제조 일자 도움 사용 후기 색깔 다홍색 느낌 기존 호랑 느낌 가격 단점 발색',
#  '먼 색이뻐요',
#  '재구매 자극 향',
#  '마스카라 용량 크기 여튼 속눈썹',
#  '모이스쳐 생각 색',
#  '향 때 하이라이터 커버 맘',
#  '제품 발색력 지속적 향 제품줌 손 제품입 디 완전 맘 쏘 옥',
#  '거사 구매 햇는데',
#  '가격',
#  '후기 해서 정도 예상 햇는데 옆 텀블러 작음 바나나 향도 발림성 상품 맘에',
#  '색감 포장',
#  '지속력 진짜 색깔 페리페라 틴트',
#  '색 색',
#  '향이',
#  '눈 화장 인터넷 구입 넘 가루 화이트 화장솜 화이트 첨 분 가루 핑크 색정 도면',
#  '클리오 다이아몬드 팩트 뒤 제품 지성 피부 화장 제품 가격 제품 포장 상태 맘',
#  '늘쓰던거 사서',
#  '색상 좋으네요 하 있지',
#  '오프라인 가격 제조 년월 인터넷 화장품 사고 적 처음',
#  '선물 색깔 배송 선물 사람 완전 맘',
#  '제품 향 샘플',
#  '라 프레리 파우더 커버력 얼굴 제품 제품 곳 백화점 라 프레리 매장 대도시 롯데 홈쇼핑',
#  '르 스모킹 고민 메인 컬러 신드롬 케이스 무광 때 자석 립 브러쉬 립 브러쉬 컬러명 뚜껑 위',
#  '별론거 눈썹 마를는 동안 자극적 눈 색상 별로',
#  '피부 화장품 얼굴 이니스프리 그린티 병 화장품 이름 저럼 색 플라스틱 병 귀',
#  '항상쓰 스킨 매장',
#  '상각 색 입술색 향',
#  '스킨 가격 마트 화장품 코너 옥션 쿠폰 제품 묶음 배송 배송비',
#  '발림성 용기',
#  '상품 에센스양 요즘 봄철 피부',
#  '입술 모양 전체적 넘 힘이 브러쉬 광택 비단 용량',
#  '막상 치즈 들어나 것같내요 향',
#  '가격 용량',
#  '양 엄마',
#  '가격 한거번 상품 가격 만족',
#  '배송 브라운 부담 도 오늘',
#  '건성 피부 지네요 흡수 향도 백화점 많 사서 정말',
#  '색상',
#  '스킨 젤리 형태 로숀 수분감 사용감 제품 업그레이드',
#  '색 잘못 산듯 언제 색 매장',
#  '지인 향 넘넘 미스트',
#  '양 색 넘',
#  '가격 맘',
#  '용량 여름',
#  '손 신경 편 촉감 덜해진거',
#  '색상 발색',
#  '늘쓰던거 쿠폰 넘 배송',
#  '배송 가격',
#  '화이트 플러스 스무딩 세럼 종 세트 클라란스 제품 매력 세럼 가격 조금 부담 스럽',
#  '가격대비 용량',
#  '제품 양이좀 듯 불구 애용',
#  '배송 핑크 썬크림 대용 씁니당',
#  '배송 제품 피부 향기',
#  '한방 피부 타입 아이오페 한율 향 아이오페 색상 다양했습',
#  '상품 대만족 색 가방 카키색 실망 냄새 애물단지 가격 만족',
#  '어요 색깔 보도 인기 컬러 이뻥',
#  '에뛰드 마스카라 중 최고 솔 모양 바 갈색 색 슴당',
#  '제품 아리따움 매장선 사은품 용량',
#  '종류 틴트 컬러',
#  '생각 용량',
#  '색 다홍 다홍 웜톤 색 발색 유분 수분기 가격 기대',
#  '앞 실리콘 팁 피부 피부 다크 써클 눈 아이보리 발림성 커버 력두 붓펜 타입',
#  '용량 향 느낌',
#  '홀리카 발색 색감 표현 거 홀리카 홀리카 섀도우 이유',
#  '아이라이너 눈 자극',
#  '향 보습력',
#  '거품 세정력 향기 만족',
#  '배송 기사 집 앞 전화 통 분명 부재시 경비실 제품 디자인 맘 아침',
#  '향',
#  '배송 상품 마음 입자 색 마음 수정 화장',
#  '배송 용량',
#  '할인 가로 색상 편 테스트',
#  '가격 만족 사용 전',
#  '케이스 기획',
#  '트리플 레드 발색 레드 모델 발색 마켓 안드로이드 앱 작성',
#  '라네즈 제품 기초 색조 화장품 편 스킨 베일 베이스 파운데이션 제품 가격 가격대비 품질 이번 느낌 편 맘',
#  '데이 로션 타입 피부 유수분 피부 화장 퍼밍 로션 파운데이션 양',
#  '라네즈 현대몰 살수 배송 느렷어요',
#  '흡수 며칠 효과',
#  '향기',
#  '다음',
#  '색상',
#  '색 색 지속력 발색 최고',
#  '처음 제품 생각 양 무향 부담 제품 편 피부 분',
#  '사이트 들 가격 양 화장품 향기 쓸거',
#  '사서 좋앗고',
#  '가격 품질',
#  '언니 용량 작지 전 제품 얼굴 피부 색 티나 정도',
#  '냄새 짱',
#  '화해 어플 주의 성분 거의 용량',
#  '평소 키엘 상품 병 용량',
#  '완전 가격',
#  '공항 면세점 피부 양 제품 가격 양 있',
#  '산거',
#  '클라란스 화이트닝 라인 에센스 향기 펌핑 가을 겨울 수분 에센스',
#  '게 처음 가격 부담 가격 최고',
#  '색상 마음 에드 질감',
#  '하루 종일 화장 색 부르주아 화이트 펄 상품평 배송료 백화점 도움 되시길색 밑에분 말 팥색 한데 분홍 펴바르 쌍꺼풀 라인',
#  '여름 미끌 향',
#  '용량 도굿',
#  '수연 진 크림 수연 크림 수연 크림 여름 수연 진 크림 여름 이후',
#  '스타 파우더 다이아 파우더 라인 펄땡이 느낌 첨 삿다 백화점 중 햇어요 입술 편 석류',
#  '쿠폰 저렴히 케이스 벨벳 촉감 품질',
#  '향도',
#  '향은 색상',
#  '가격 대비',
#  '향 건성 제품 가격 정말좋 제품',
#  '입구 디자인 색상 넘맘에',
#  '엄마 설화수 이번 팩트 케이스 향 마음 샘플 감사',
#  '설화수 비비 씨씨 가격 용량',
#  '향 스프레이 펌프',
#  '건조 한지 향',
#  '엄마 콤팩트 모양 배송',
#  '처음 가격 준무해 가품인것 정품 배송',
#  '고보습 고보습 피지 오겔 때 느낌 무게감 향',
#  '마스카라 사용 중 색상 마음 계속',
#  '연령대 초반 피부 타입 건성 지성 복합성 건성 제품 사용 횟수 기간 사용 중 제조 일자 도움 사용 후기 옥션 안드로이드 앱 작성',
#  '용량 맘',
#  '비비 크림 커버력 트러블 사용 중 가격대비 용량 타사 가격대비 효율 성적 면 대만족',
#  '친구 색 있엇으면 아쉬움 수정',
#  '가성비 용기 디자인 세련 피부 표현 좋으네요',
#  '품질 디자인 가격 배송 마음',
#  '거라 여름 쓰기',
#  '제품',
#  '써봐야알겠지 느낌상 얼굴 양이 때 살수',
#  '화장품',
#  '시슬리 제품 향 아 로마 효과 겨울 괜챦',
#  '발색 편이 양',
#  '향 여자 향수 냄새',
#  '발색 색감 지속력 첨 밥 자녁때쯤 때',
#  '색 잘못 첨 양 냄새',
#  '가격 구입 향 저가 냄새',
#  '처음 느낌 향기',
#  '메이블린 때 느낌 이번 산거 발림감 부분 확실 차이 한올한올 느낌 느낌 이번 만족',
#  '향 얼굴',
#  '번째 알로에 랑 흡수 예정',
#  '배송 제품 파 세용',
#  '타투 기능 셈 붓펜 아이브로우 산거니 색 진',
#  '주기적 제품 점 중간 토너 토너',
#  '용량 향',
#  '향 흡수력 느낌 향',
#  '향',
#  '기획 샘플 진짜 샘플 틴티드 모이스쳐 지금 제 피부 진짜 마지막 단계 이 화운데이션 대신 피부 자극 이번 제품',
#  '제품 대용량 기획 세트 스킨병 아침 저녁 리필 용기 이번 기획 세트 용량 한동안',
#  '모양 슥슥 색상 구매',
#  '타입',
#  '제피 부가 편 용량 프랑스 꺼 만',
#  '발림',
#  '색감 너무진하지',
#  '색 넘',
#  '색감',
#  '파운데이션 커버력 밀착력 붓',
#  '품질 용량 넘 대용량 좋겟어요 제품',
#  '지속력 소량',
#  '여름 피지 오일 프리 제품 제품 향 자극적 크림 찐덕 거리',
#  '디자인 색상 품질',
#  '성분 다음 용량 꺼예용',
#  '연령대 피부 타입 건성 지성 복합성 제품 사용 횟수 기간 제조 일자 도움 사용 후기 건성 피부 겨울 생각 옥션 안드로이드 앱 작성',
#  '배송 진짜 가격 제품 배송 딱하나',
#  '피부 향 제품 할인 쿠폰 가격 배송 화장품',
#  '색상 디자인 넘 가격 대만족 립 제품 갠취 외국인 친구 선물 부담 구매',
#  '종이 케이스 향 펄',
#  '작은병 큰걸 가격',
#  '색상 발색',
#  '색 가격 디자인 만족 섀도우 아이라이너 배송 저번 물건 때 배송 문제',
#  '지속적 여드름 피부 말 미리 양 크리니크 걸름 뚜껑 제품 제조 일자 일자 최근 브랜드 데이 상품',
#  '색상 발색도 지속력 도우수 한편 간만 립스틱 가격',
#  '색상 냄새',
#  '립글로스 인데 발색 용량 재구매',
#  '베리떼 쿠션 이야기 앨리스 에디션 맘',
#  '슬리밍 제품 용량 쓸거',
#  '배송 정말빨 아벤느 제품 첨써 저랑잘 용량 오래 거다 화장수',
#  '양 가격 배송',
#  '제품 처음 인터넷 산거',
#  '가격 완전 사서 언니 사용 전 좋으것 가격 완전 사서 언니 사용 전 좋으것 가격 완전 사서 언니 사용 전 좋으것',
#  '발색 실물',
#  '에뛰드 플레이 컬러 아이즈 피치 팜 순서 보고사 용해 저에겐능숙 에뛰드 팜 인더 카페 색상',
#  '가을 컬러 레드 발림성 유분 용량',
#  '색조합 맘',
#  '샘플 향',
#  '라네즈 꺼 투톤립바 기존 기존 색상 뱀파이어 입술',
#  '아이 향',
#  '배송 하루 박스 안 비닐 여름 모공 신경 제품 용량 소량 프라이머 라유 안 미니 사이즈 미니 사이즈 용량 일년 안',
#  '배송 색도',
#  '오프라인 온라인 가격 맘',
#  '휴대 용도 일반 수분 크림 계속 쓸예정이',
#  '집 비비 샘플 는데 밀착감 커버력 장난 피부 코부분 제품 인가 는데 겟 잇 뷰티 제품 가격 제품 디자인 옥션 안드로이드 앱 작성',
#  '양',
#  '용량 여름 한철 촉촉',
#  '용량 용량',
#  '랑콤 프리모디알 스킨 케어 라인 세트 나이트 크림 이랑 에멀젼 나이트 크림 나이트 크림 괸장히 피부',
#  '악건성 키엘 수분 크림 저녁 아침 뽀로지 기우 향 그닥',
#  '임블리 상품 양',
#  '디자인 향 향기 나네요 마몽드 짱',
#  '번째 한데',
#  '향 예전 사은품 미니어처 향',
#  '샘플 맘 배송',
#  '아오 대용량 저번 사이트 샘플한개 제니피끄 제품 자체 대용량 쿠폰 샘플 완전 요즘 피부',
#  '오프라인 상의 샵 만원 이상 구입시 할인 행사 사은품 온라인 최강 상품 사은품',
#  '해외 배송 생각 전화 판매 자분 기분 용량 완전 물 클렌징 기능',
#  '용량',
#  '제품 피부 수분 밸런스 향 흡수 크림',
#  '사이즈 처음 사이즈 넘 금방 짱이 가격 용량 곡정없',
#  '향 남자',
#  '색 여름 뮤트톤인 친구 걔 찰떡 의문 선물행 색자체 채도 웜톤 쿨 뮤트 라이트 색 가을 뮤트정',
#  '가격',
#  '샘플 가격 모공 느낌',
#  '미샤 향',
#  '디자인 배송',
#  '발색 컬러 넘 배송 금상첨화',
#  '가격 샘플',
#  '샘플 맘에 사은품 중 빅퍼프 대신 폼 클렌징 빅퍼프 사은품 오일 용량',
#  '상품평 세개 브라운 색상 느낌 전 외국 제품 헤라 가격 이고 강추',
#  '가격 제품 배송',
#  '파우치 귀얍고 라니 여름 끝나고 가을 케이스 너뮤',
#  '미사용 색 사은품 감사',
#  '색상 발림성',
#  '여행 때 슬리퍼 목베개 제품 샘플 택배 기분 제조 일자 포어 제품 향',
#  '코랄이 컬러 넘이뻐요 지속 배 송도 가격 삿네요',
#  '재구매 커버 용량 작지 오래쓰 편이',
#  '제품 고민없 용기 양이좀 점 배송',
#  '뿌리 맘',
#  '배송 제품 몸 색깔 값 다음',
#  '가격 좋았느데 배송 시중가',
#  '배송 모낭충 피부 가격',
#  '가격 가성비 면 학생 거 후반 무리 인거 장난감 색 분 티나 쨍한색 거 장미색 색 얼굴 생기 안도는거',
#  '바디 로션 향 미스트 가방 사이즈 향수 대용',
#  '겔랑 파운데이션 용량',
#  '가격 평소 때 산것 배송 편 만 성능 크림 발라 속 쓰고 느낌',
#  '피부 결도좋응것',
#  '밤비걸 영상 보고 홍시반시 컬러 컬러 맘 발색 가격 마스카라 리무버 샘플',
#  '제품 컨실러 발림성 커버력 사용',
#  '온브러 싼티 안나구좋으네영 색상 영 배송빨랏음',
#  '향 잘삿 어용 배송 상품 맘',
#  '사은품',
#  '느낌 발색 별로',
#  '마무리 조아',
#  '향 제일조 은거',
#  '금색펄 넘',
#  '배송 색 화장기 맨 얼굴 색감 발림성',
#  '가격대비 용량',
#  '색상 마음 디자인',
#  '백화점 가격',
#  '가격 양',
#  '색조 상품평 발림성 색깔 색상 색 브러쉬 셋트 끈 검정색 브러쉬',
#  '양 퍼프 가격 제품 샘플 빈박스 요거 맘',
#  '양 쓸거 다음 에도 재구매 마켓 안드로이드 앱 작성',
#  '선물 가격 비표 제거 상품 상품 샘플 단품 가격대비',
#  '용량 배송 편이 건조 한편 향 바디 로션 오랜만',
#  '백화점 언니 설명 처음 제품 완전 만족 건성 피부 샘플',
#  '샘플 보고 쫀',
#  '사이버 화이트 시리즈 생크림 브랜드 가격 효과 나이트 크림',
#  '색감',
#  '크기 사이즈 여행 때 프로 쿠폰 완전 브라운 계열 계열 배송은쪼금늦었지 번창하세욤',
#  '배송이넘 흡수 넘',
#  '아이오페 쿠션 종류 커버 발림성',
#  '엄마 디자인 맘',
#  '지성 피부 여름 젤 타입 향 편 명품 화장품 대비 품질 가격 샘플 지성 피부 여름 젤 타입 향 편 명품 화장품 대비 품질',
#  '입소문 평 제품 오프라인 샘플 용량 생각',
#  '제품 가격 품질 디자인 때 느낌 주변 사람',
#  '용량',
#  '학생 색깔 버건디 라기 바이올 릿 레드빛나 반짝이 싼티가 여튼 구매 엿다기 도전적 구매',
#  '자극 식구',
#  '예전 상품 가격',
#  '색상',
#  '미백설 라인 에센스 펌핑 때 알갱이 미백 작용 효과 사용감 흡수',
#  '가격',
#  '고급 스려워요 부모님 선물 로',
#  '색감',
#  '지난번 한번 구입 후 끈적임 세정 디자인 트러블 한번 난적 재구매',
#  '가격대비 흠 흡수력 제품',
#  '백화점 사 하루 종일 향기 가격 흠 행사 해서 색깔 실망 색깔 표시',
#  '향',
#  '천연 사용감',
#  '양',
#  '매트 앞 케이스 색 랜덤 걱정 꽃 디자인 만족 싸이즈 부피 발색력',
#  '양 느낌 화장',
#  '제품 인터넷 수분 약간 보습',
#  '진짜 작고',
#  '가격 색상 맘 강추',
#  '산거 배송 맘',
#  '용량 홈쇼핑 아이 아토피 용량 홈쇼핑 정품 마크 촉감 배송',
#  '병 디자인 전 양',
#  '순간 흡수',
#  '발림성 편이',
#  '클라란스 녹색 라인 색 라인 처음',
#  '배송 원료 향도 가격 자주 애용하겠음돠',
#  '양 유수분 배송',
#  '상품명 제품 이번 에센스 느낌',
#  '끈적임 이하나 보습도 향도 브랜드 값이라 가격',
#  '효과 프라이머 티 프라이머 중 얘 양도 대따',
#  '밤 피부 맨질맨질 엄마 양 행사 기간 완전 잘산듯 흰색병 로션 세트 완전 겨울 피부 분 두번',
#  '배송 향 짱짱맨',
#  '일단 만족 스킨 제조 에멀젼 제조 인지 가격 샘플 기대',
#  '향이 제품 흡수력 사용 히기 가성비짱',
#  '아들 피부 얼굴 형식 아들 피부 샘플 듬북',
#  '효과 가격',
#  '타싸이트 가격 배송 넘 제품 라인 제품 기초 제품 이번 향 강추',
#  '백화점 지금 구입 원정 요즘 환절기 특유 향 이향',
#  '전 양 대용량 얼굴 전체 펴바 정도',
#  '향',
#  '샘플 본품 용량 짱짱 때 정도',
#  '발색 생각 용량 케이스 맘 후회',
#  '가격 디자인 피부 모두모두 마음 할인 가격 앞 할인 이벤트 해주 세용 에뛰드',
#  '마몽드 파운데이션 기초 마몽드 가격대비 이번 파운데이션 기존 이름 생각 양',
#  '향도 상품',
#  '향',
#  '이마 좁쌀 좁쌀 효과 눈 효과 발림성',
#  '연령대 피부 타입 건성 지성 복합성 제품 사용 횟수 기간 제조 일자 도움 사용 후기 블루 크리스마스 랑 스파클링 로제 깨짐없 펄감 블루 크리스마스 블루펄 매력 베이스 색상 편 옥션 안드로이드 앱 작성',
#  '품질 디자인 가격 배송 마음 나스',
#  '전 제품 제품 좋으네요 향',
#  '향',
#  '향',
#  '배송 한정판 핑크',
#  '엄마 선물 사드렸느데 디자인 품질',
#  '예전 성분 좋아진거 향 좋으네요 이번 엄마 담',
#  '민감 피부 트러블 분사력 굳촉크 초크 향 별도 양도',
#  '제품 복합성 피부 존 존 고민중',
#  '맨날쓰 바이오 하이드로',
#  '향',
#  '두껑 모양',
#  '색상 괜찬앙',
#  '배송비 않 클리오 괴안은듯',
#  '주위 말',
#  '입술 향',
#  '신상 벌집 모양 쿠션',
#  '예전 쓰리컨셉 립스틱 이번 역쉬 색상 발림성 색상 립스틱',
#  '펄감 펄감 외관 화면 상 아이 메이크업 색 펄감 펄감 외관 화면 상',
#  '피부 알러지 피부 적극 가격 양 유분끼',
#  '립바 가격 배송 토요일 토요일 배송 마켓 아이폰 앱 작성',
#  '제품 이번 가격 배송 다음날',
#  '헤라쿠션 다음 재구매 의사',
#  '제품 배송 배송 배송',
#  '크기 냄새 개인적 취향',
#  '베이지 품절 한정 제품 인가 오렌지 색상 베이지 펄 립스틱 색상 마음 가을 립스틱',
#  '번째 주문 좋은 상품 향 강추',
#  '얼굴 붉은기 발림성 홍 조',
#  '향 사용감 빌리프 중임',
#  '색 발림 지속',
#  '약 냄새 저자극 일째',
#  '라네즈 스킨 로션 에센스 수분 크림 배송',
#  '냄새 질염 거같아여 마니파',
#  '향 사이트 가격 비교 해서 인터파크 가격 제품',
#  '화면 색상 차이 나지 글로 시한 느낌 발림',
#  '비오템 수분 크림 중복 합성 이번 대용량 색상 피부 느낌 감사 합닏',
#  '매장 보습력 향 스킨 로션 손바닥 차례 두두려 손바닥 용기 용기 보습',
#  '가격 배 송도 진짜 구조 아여 커버 효과 굿 팩트 앞 두쭉 재구매 마켓 안드로이드 앱 작성',
#  '색감 넘',
#  '사진 색 발색 색',
#  '선물 포장 건성 피부 지복합성 무 흡수 저녁 피부 트러블 수분 부족',
#  '샘플 가족 본품 모이스처 핑크 워터리 하늘색 요상품 피부 커버력',
#  '자극적 중지성 피부 향 인공적 느낌없 가격',
#  '양 정도',
#  '가격',
#  '기분 탓인 가용 샘플',
#  '배송 색상 발림 맘 누드 메이크업',
#  '여자 친구 다행 포장 상 제주도 하루 만 배송 여자 친구 다행 포장 상품',
#  '레드 성애자 빨강 발림성',
#  '사이즈 이번 용량 양',
#  '유 빅 뷰티풀 튜토리얼',
#  '토요일 오후 어제 월요일 배송 짱 치크 팝 나만 템 데이 할인 발색 컬러 패키지 치크 팝',
#  '배송 화장 사람 어른 화운데이션 마무리 분 분 색상 때 맘 하루',
#  '여름 화장품 느낌 제품 자체 괜찬네요 향 뚜껑 뚜껑 위 천사 디자인 거 가격',
#  '색상 구성',
#  '스킨 스킨 정도 코코넛 향 호불호 좋',
#  '냄새 사서 사은품 종 세트 이번 수분 라인 여행 세트',
#  '펜 부분 색 생각 했더 색 맘',
#  '록시땅 편 제품 처음 며칠 효과 방울 정도 오일 제품 베리',
#  '한번',
#  '피부 흡수',
#  '제품 양 발림성 예전 제품',
#  '친구 샘플 색감 좋으네요',
#  '배송 꽝 사용 전 용량 생각 배송 꽝',
#  '크기 용량',
#  '양',
#  '사용감',
#  '샘플 조금 분홍색 펄',
#  '배송 오일 향 여름',
#  '라벤더 오가닉 샤워 젤 향',
#  '발색 색상',
#  '스킨 로션 여자 화장품 회사 것 훨 조금 써 화장시 화장품 피지 좋 엄마 이번 사드림요',
#  '컬러 펄 제품 오래 오래 쓸듯',
#  '때 색깔',
#  '연한색 전 산거 느낌',
#  '웬일 샘플 체험 당첨 공짜 값 저녁 단계 아침 화장 피부 때 느낌 피부 스면드 속도 크림',
#  '한방 화장품 향',
#  '배송 포장 좋으네요',
#  '가격 세트 진짜 럭키 오래 쓸거 화장품 냄새 갠찬네요',
#  '드됴 할인 쿠폰 백화점 만원 정도 백화점 가격대비 성분 효과적 순수 비타민 성분 향 향 자극적 통 때 효과',
#  '바비 브라운 립스틱 선물',
#  '배송 양',
#  '배송 알려쥬 생각 사이즈 디자인 이브',
#  '가격 기존 만원 배송',
#  '평 가격 완전',
#  '걸 일할 때 입술 립글로스 메니큐어 붓 입술 배송 예정일 여름',
#  '제품 용량 한통 끝 두번 이제',
#  '베네피트 가격 압박 디자인 사용 후기 편 처음 용기 디자인 패스 내일 _',
#  '제품 색상 제품 색상 제품 색상 만족',
#  '시즌 아이크림 흡수 시즌 성분 시즌 흡수 해서 때 개인적 건성 한데 기름 진건 해서 성분 흡수',
#  '립스틱 디자인 누드 베이지 글로시 해서',
#  '품질 디자인 가격 배송 마음 조아',
#  '케이스 사이즈 맘 결정적 립스틱 질감 실망 펄때문 입술 입자 느낌 신청',
#  '향 난후',
#  '제품 인터넷 저렴히 아모레 퍼시픽 포인트 수분 크림 수분 크림 것도 추천',
#  '가격',
#  '타입 펄감 발림 완전',
#  '모르겟어요 느낌 가격 양 생각 넘',
#  '색상 후기 미세 먼지',
#  '스킨',
#  '향 용기',
#  '스킨 로션 헤라꺼 이번 에이지 어웨이 바깟는데 포장',
#  '가격 건성 꾸덕한 크림 발라 면 때 때 못쓰겟고 걍집 때',
#  '색 피부톤',
#  '세일 기간',
#  '발색 색 구성',
#  '가격 신세계 기획 상품 _',
#  '가격 만족',
#  '컬러 넘',
#  '립 크로스 가격 약간 부담 스럽지 브랜드 데이 행사 체리색 색깔 크리니크 마스카라 샘플 마스카라 샘플',
#  '크림 특유 냄새 건성 유분기 크림',
#  '색상',
#  '스킨 에센스 크림 삿는데 게 느낌',
#  '넘 지금 차앤박 수면팩 사용 중 비비 에센스 넘 양 그닥 앰플 농축액 쓸거 아이템 중',
#  '탈크 이니스프리 노세범 파우더 성분 용량 가격 노세범 파우더 이니스 마몽드 가성비면',
#  '가격',
#  '사실 비비 크림 제품 세개 이번 고민 상품평 오리지날 양 발림성 지속력',
#  '미샤 할인 데이 추가 쿠폰 해서 저렴히 느낌 케이스 배송',
#  '지성 안티블레미쉬 라인 수분 거 클래리파잉 용량 효과 처음 생각 유분 블',
#  '향두',
#  '두번 정도 스킨팩 해봤 자극 냄새 잘모르겟어요 엄마 햇엇어요',
#  '브랜드 가격 효과 백화점',
#  '크리니크 모이스춰 엑스트라 아침 제품 기초 단계 밤 지복합성 피부 재생 효과',
#  '시세이도 색조 자체 아이라이너 화장 대명사 제품 아이라이너 정도 해서 효과 속눈썹',
#  '용량 생각 용기 플라스틱 염려',
#  '엄마 선물 엄마 화장품 브랜드 가격',
#  '처음 때 색 생각 발림성 색',
#  '메이크업 완성 메이크업 완성 메이크업 완성 마켓 안드로이드 앱 작성',
#  '향 디자인 시어 버터 향 여름 체리블러썸',
#  '통 피부 건성 바디 로션 느낌 제품 날 겨울 향 번째 파라벤 프리',
#  '샘플 향 넘 맘 사용 중 여름 감 재구매',
#  '용량 넘 마음',
#  '아기 피부 편 로션 크림 로션 통 크림 냄새 크림 제형',
#  '세일 망설임 디자인 마음',
#  '기능성 향 때 용기',
#  '순간 느낌',
#  '선물 최고 색 사은품',
#  '피부 점 효과 브러쉬 블러 효과 계속 쓸듯',
#  '평소 내츄럴 메이컵 색 립 컬러 딱이죠토인삘 안나 누디 핑크 손발 색 입술 진짜 발색 핑크 발림성 각질 부각 미끌 거리 덧발라 뭉침없 입술',
#  '매장',
#  '요번 엄마 생신 선물 향뿐만 디자인 마음 보습력 엄마 거',
#  '보습 기능 가격 대만족',
#  '색상 커버력 굿 매각',
#  '오일 느낌 오일 오일 끈적임 끈적 이질 피부',
#  '그전 핑크 글로우 이번 핑크 브론즈 개인적 브론즈 맘 쉐이딩 섀도우',
#  '소문 스킨 피부 정돈 역할 기능성 필요 가격 편',
#  '색 블러셔 스킬이 필요 흰끼',
#  '키엘 수분밤 우 화면 아이스크림 조금 걸죽 크림',
#  '피부 수분 크림 때 트러블 쿨링감 배송',
#  '배송 에스티로더 저렴이 에스티로더 커버력 유분기',
#  '엄마 해라 가격 향 하루 길 아모레 퍼시픽 판메 사원 샘플 인터넷 정보',
#  '럭키 에디션 케이스 어무 만족 제품 배송',
#  '쉬머한 펄입자 발색',
#  '제품 리필 가격',
#  '향 발림 보습',
#  '배송 피부 슈퍼 바이탈 최고 넘',
#  '조아 인터넷',
#  '색깔',
#  '두번 조은지 헤라 향 케이스 거 양이 보여 헤라',
#  '판매자 가격 배송',
#  '피부',
#  '다음날 색상',
#  '오프라인 구매 브라운',
#  '발림 피부 트러블 기본 라인',
#  '건성 에센스 용량 제품',
#  '진짜 배송',
#  '제품 발림감 꾸준이 제품',
#  '뷰티유투버분 저렴이 글리터 랑 아침 밤 뭐발랐냐 질문 정도 생각 면봉 맘',
#  '가격 물건 평소 기초 제품 앞 가격 구매',
#  '용량 향기 수분기 모르겟',
#  '오배송 시간 키트 일 처리 제품 자체 끼 보정 하이라이트 다크 커버 발림성',
#  '색깔 스타일',
#  '양 넘 한통 기분 기능적',
#  '전체적 부분적 제품 인거 향 효과 영',
#  '동생 향 피부 주문 광복절',
#  '천삼선유 제품 품격 배송 특배송 한방 화장품 게 향',
#  '스킨 대신 용량 맘',
#  '색상 상품 편 여름 괜찮 상품',
#  '수분 크림 사무실 이드라젠 수분 크림 요즘 겨울 이샵 랑콤 을 제네피크 썬크림 스킨 로션 전부',
#  '색상 마음 검정 붓끝이 문제 요령 양두 넘 적구 때 깨끗 하',
#  '구입',
#  '색감도',
#  '가격 배송 색깔',
#  '색상 발색 거 볼터치 광택감 베네피트 볼터치 시리즈 마음',
#  '옆 빈병 레몬향 매번 구매 해 향 신경 강추 마켓 안드로이드 앱 작성',
#  '동생 제품 리바 이탈 화이트 시세이도 기초 대만족',
#  '가격 배송 무지',
#  '연령대 중반 피부 타입 건성 지성 복합성 건성 제품 사용 횟수 기간 구매 제조 일자 도움 사용 후기 품질 가격 건성 피부 하루 옥션 안드로이드 앱 작성',
#  '저녁 기초 케어 향 버터향',
#  '목요일 토요일 수령 뽁뽁이 포장 기존 상품 에센스 여름 느낌 에센스 점 샘플 점 점 피부 가격 쿠폰 이랑 카드 할인 곳',
#  '용기 싼티 아쉽',
#  '발림성 로션 가격 넘 별',
#  '디자인',
#  '향기',
#  '입술 모양 케이스 떡칠을 만건지',
#  '설화수 구입 값 흠',
#  '리필 제품 가격 거품',
#  '전 에뛰 샘플 여 향두 겡',
#  '색상 모양 맘 색상 모안 도 큐디 맘에',
#  '옆 바이오 에센 요거 상품평 이좋 기도 세일 에센스 차 요이이 사용 향 발효향 넘 옆 바이오 에센 요거',
#  '데이트 버터 크림 처음 크림 수분 지속력 비비 크림 때 피부 가격',
#  '가격',
#  '색 향',
#  '가격 대의 타사 에센스 화장품 크림 냄새 전형적 화장품 냄새 향 제품 성능',
#  '딸',
#  '상품 립스틱 제조 일자 월이 년 제품 가격 다운 것도 신세계 요즘 색은 걍쓰겠지 제조 일자 눈을 인터넷 사도 오래',
#  '최근 성분 용량',
#  '인터넷 더 샘 컨실러 김 앰플 용량 생각 스포이드 효과',
#  '아이오페 슈퍼 울트라 비비 아모레 라인 중 전 거 가격 배송',
#  '색깔',
#  '가격 저렴 인당 씩 슬펏어요 다량',
#  '디자인 에뛰드 붓 힘이 발색 비추',
#  '색상 맘',
#  '쌀 기획 추가 한율쌀 진액 마스크 시트 비매품 전 마스크 씨트인줄 제목 표지 시트지 제품 분 참고 내용물 양도 비매품 택배비 아모레 퍼시픽 상품 회사 지장 정말 실망 입니댜',
#  '향 맘',
#  '양 향 거품',
#  '피부',
#  '색깔 화면 상 실제색 봐',
#  '배송 트러블 제품 남자 스킨 박하향 향 요즘 뽀드락지 패스',
#  '발림성 모이스처 마스크 크림 배송',
#  '기미 상품 이에요 흡수력 얼굴 전체 느낌 이에요 적극 추천',
#  '브라운 지성 피부 타입 파우더 색 연 자극 돈',
#  '색깔 펄 조금 매혹적 색깔 색감 맘 드고 케 파우더 색깔 펄 조금 매혹적 색깔 색감 맘 드고 케이스 넘',
#  '사용감 피부 편',
#  '제품 처음 발림',
#  '인터넷 미백 제품',
#  '향',
#  '화장 때 저번 넘 화장',
#  '용량 가격 저렵 한데 효과 백탁 현상 꾸덕하지 피부 자극 다음날 뽀송해료',
#  '생각 디자인',
#  '색상 진짜',
#  '색깔',
#  '사이즈 용량 용량 인거 전 아침 각질 없너요 효과 짱인거',
#  '마음 디자인 수정 화장시 불편 피부 기분',
#  '배송 생각 디자인 틴트색 색',
#  '배송 확인 처음 제품 향 마사지 크림 사용 전 아모레 제품 느낌 바래 가격 괜찬은것 디자인 피부',
#  '샘플 보고 산것',
#  '용량 가격 이마 눈주위 팔자 주름 가격대비 거',
#  '색상 완전 단독 바르기 부담 스럽 오렌지 라고하기 레드라하기 약간 핑크 오렌지 색 향 넘 단독 바름 넘 써야겠 립글 레이즈',
#  '색상 텐더 페탈 분홍색 느낌 들것',
#  '배송 향도',
#  '오리진스 제품 처음 처음 넘 향 진짜 이제 수분 크림 오리진스 사용 할거 만족',
#  '색상 디자인 모두 맘에',
#  '색 눈 때 실제 발색 모델분 이미지컷 완전 벽돌색 느낌나 브라운 겨울 적극 믿고사 삐아',
#  '핑크빔 발색 편',
#  '조카 포장 용기 좋내요',
#  '예전 효과 엘지 품질 가격 엄마 스킨 로션 도',
#  '샘플 쪼오꼼 향 색감 진짜',
#  '집사람 향 디자인 센스 통 재활용 센스 선물',
#  '가격 색깔',
#  '찰진 에센스 양',
#  '세일 기간 동생 마켓 안드로이드 앱 작성',
#  '엄마 선물 엄마 색 색깔 거 맘',
#  '화면 색상 색인',
#  '사용 전 양 가격',
#  '겨울 수분 로션 상품평 피부',
#  '색상 맘 셰도 팔레트 가격',
#  '제품 종이 박스 제품 주변 파우더 뭍어 파우더 통 통 양 별로',
#  '스킨푸드 제품 대체적 냄새 저라 장미향 좋으네요 포장 왕친절 기사 아저씨 맘 듧니다',
#  '여름철 땀 냄새 대비',
#  '동안 지인 후 쌤플 파우더 인터파크 대체품 고급 후 리필 불편 색상 맘',
#  '배송 사서 엄마 선물 잘해쪄',
#  '딸 때 딸 기존 제품',
#  '피부 이자 녹스 화장품 가격 추가 구성 맘',
#  '매장 배송',
#  '배송 질감 홍조 색상 여리 맘',
#  '향 촉촉함',
#  '싸이닉 수분 크림 빨강 젤리 까망 젤리 아쿠아 젤리 빨강 젤리 크림 까망젤리랑 아쿠아 젤리 촉촉함 싸이닉 수분 크림 라인',
#  '연령대 대피부 타입 건성 지성 복합성 중건성 제품 사용 횟수 기간 사용 제조 일자 도움 사용 후기 립 무스 타입 립 제품 사서 한동안 사용 컬러',
#  '엣센스 찰나 눈 제품 용기 쌤플',
#  '색상 종류 화장 담 색상 겟어요',
#  '메이크업 베이스 이니스프리 바닐라 인기',
#  '제품 한방 성분 피부 향기 건성 피부',
#  '완전 디자인 서비스 팩 엄청촉촉 조아',
#  '향 마음',
#  '어제 아이오페 실망 잘산거 오프라인 정가',
#  '가격 상품',
#  '랑콤꺼 아이라 펜슬 이번 김하늘 립스틱 저번 이번 무료 배송 색 펜슬깍이 부착 점 용량 작네염',
#  '색깔 향기 느낌 틴트 느낌',
#  '알콜 냄세 향 이번 번째 구매 별일 앞 상품',
#  '형광끼',
#  '설 연휴 택배 편 포장 연보라 색 케이스 색감 때 볼일 집 때 지지 밀착력',
#  '체리향 향 발색 구매 핸는',
#  '양',
#  '피부 자극 가격 부담',
#  '키엘 크림 중 제일 유분 수분 크림 촉촉함',
#  '색감이뻐욤 미 이 미 미 미업디벚데뱌 베 미암',
#  '연한 핑크 처음 봄 좋 색 핑크',
#  '상품평 구매자 이상 제품 병이 양 제품으 정말 조금 얼굴 꿀광 피부 마니 가격대비 제품',
#  '지성 복합성 피부 트러블 저 크림 토너 에센스 생각 크림 세안 후',
#  '펌프식 위생적 맘 디자인 좋은 상품',
#  '백화점 통 피부 양 스킨 양',
#  '사용 배송 가격 맘',
#  '발림성 최고 피부 트러블 사용감 다이소 펌핑 공병하 추천',
#  '굿굿 향 가격',
#  '유수분 밸런싱 에센스 싸이닉 불가리안 로즈 매직 테라피 에센스 향이 것 피지 조절 피부 탄력 에센스',
#  '아이 섀도 발색 편이 색상 맘에 시간 아이 섀도 발색 편이 색상 맘에 시간 깊이 눈 필름지 아이새 방법 솔번호 배려 만족',
#  '냄새 한참',
#  '색상 넘',
#  '가격',
#  '전 면세점 색깔',
#  '세일 기간 매장 사서',
#  '인터넷 화면 물건 바다 형광 색 자체 빛 핑크 빛 틴트 자체 입술 각질 편',
#  '않 디자인 맘',
#  '냄새 아이',
#  '용량',
#  '비오템 크리니크 가격대비 효과 거 앞 써봐야알겠지 흡수',
#  '예전 샘플 적 발림 피부 보호막 발림',
#  '얼굴 가루 날림 색깔 손등',
#  '연령대 대피부 타입 건성 지성 복합성 건성 제품 사용 횟수 기간 번째 제조 일자 유통 기한 임 도움 사용 후기',
#  '향',
#  '색상',
#  '루나 사람 견미리 팩트 루나 팩트 커버 이번 디자인',
#  '엄마 향 아이오페 썬블럭',
#  '색 배송 마음',
#  '스킨 큰걸 기능 용량 대비 진짜 이하 샘플 다라 안내문',
#  '색상 발색력 색조 바비 브라운',
#  '상큼한 레몬향 양도',
#  '디자인 마스카라 용',
#  '좋으네요 화장',
#  '향 발림성 좋겟어요',
#  '양 통 착색 이랑 머리 색 앞',
#  '매장 케이스 매장 언니 집 롯데 아이몰 쿠폰 색감 데일리',
#  '날씨 마몽드 토탈 솔루션 향 디자인 덤 세럼 다음',
#  '연령대 피부 타입 건성 지성 복합성 건성 제품 사용 횟수 기간 일주일 제조 일자 도움 사용 후기 악건성 제품 질감 느낌 향 여별 자극',
#  '향',
#  '수분 크림 제품 평 마음 주문 수분 크림 이라기 유분 영양 크림 느낌 영양 크림 질감 느낌 유분감 마사지 크림 마무리 피부 느낌',
#  '생일 넘 케이스',
#  '로즈향 평소 제품 향',
#  '리미티드 병 디자인 설화수 사람 해서',
#  '구매 색 배송 구매',
#  '라네즈 스킨 이번 라인 배송 용량 진짜 언니 동생 제품 외제 브랜드 라네즈 스킨 제일 피부 자극적',
#  '극 민감성 피부 대학 병원 피부과 의사 선생 올리브 영',
#  '익스트림 이스트 요걸 리뉴얼됐대 서구 피부 경향 아이 보리 딱 가격대비 용량 결점',
#  '배송 편 집 샘플 넘 크림 밀림',
#  '스킨 대용',
#  '가격 배송 맘 사용 중',
#  '용량 비비',
#  '최근 화장품 중 최고 때 사서 가격 디자인 기능 최고 속눈썹 필요',
#  '생각 양 케이스',
#  '크림 예요배송 피부 폭발 배송중 번가 고객 센터 연락 상품 가격 맘',
#  '상품 품질 마음 디자인 게 은근 기분 피부',
#  '생신 선물 양 사람',
#  '패키지 싼티',
#  '에센스 타입 스킨 용량 제품 인지 피부 타입 분',
#  '엄마 항상쓰 제품 엄마 항상쓰 제품',
#  '비타민 화장품 여드름성 피부 타제품 비타민 세럼 효과 비타민 가격대비 용량 맘',
#  '정가 사서 컬러 구성',
#  '아이 피부 요 쫀득 번째 구매 용량 발라주는데',
#  '배송 중 흠 후 화장 색 컬러 가격 배송',
#  '커버력 색',
#  '향기',
#  '향',
#  '배송 완전 담 가격 양도 제품 괜찮 은거',
#  '집 스킨 수분 크림 악건성 전 유분기 고 향료 눈시림 가격',
#  '잇츠스킨 발림성 색',
#  ...]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()

# %%
X_train_vectors = tfidf_vectorizer.fit_transform(X_train_corpus)
X_test_vectors = tfidf_vectorizer.transform(X_test_corpus)

# %%
print(X_train_vectors.shape)
print(X_test_vectors.shape)

# %%
X_train_df = pd.DataFrame(X_train_vectors.toarray(), columns=tfidf_vectorizer.get_feature_names())
X_test_df = pd.DataFrame(X_test_vectors.toarray(), columns=tfidf_vectorizer.get_feature_names())
y_train_df = pd.DataFrame(train['y'].values, columns=['target'])
y_test_df = pd.DataFrame(test['y'].values, columns=['target'])

# %%
target_names = list(set(train['y']))
target_mapping_table = {}
for idx, names in enumerate(target_names):
    target_mapping_table[names] = idx

# %%
X_train_df.head()

# %%
y_train_df['target'] = y_train_df['target'].map(target_mapping_table)
y_test_df['target'] = y_test_df['target'].map(target_mapping_table)

# %%
train_df = pd.concat([X_train_df, y_train_df], axis=1)
test_df = pd.concat([X_test_df, y_test_df], axis=1)

# %%
X_train_vectors.toarray().shape

# %%
X_test_vectors.toarray().shape

# %%
train_df.head()

# %%
test_df.head()

# %%
from sklearn.decomposition import PCA

# PCA 모델을 생성
before_pca = PCA(n_components=2) # 주성분 갯수
before_pca_train_result = before_pca.fit_transform(X_train_vectors.toarray()) # PCA 적용

# %%
before_pca_train_df = pd.DataFrame(before_pca_train_result, columns=['r0', 'r1'])
before_pca_train_df = pd.concat([before_pca_train_df, y_train_df], axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 15))
sns.scatterplot(x='r0',
                y='r1',
                hue='target',
                s=100,
                palette=['red','orange','yellow','green','blue','purple'],
                data=before_pca_train_df)

plt.show()

# %%
from scipy.sparse import isspmatrix
isspmatrix(X_train_vectors)
# Out:
# True
